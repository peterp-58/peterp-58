# %% [markdown]
# <a href="https://colab.research.google.com/github/peterp-58/peterp-58/blob/main/CIND820_PP_Bankrupcyv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import files

# %% [markdown]
# #Uploading and setting up the Polish Dataset
#
# uploading and renaming the columns for further review of the polish dataset.

# %%
#pulling data from the website.
polishData=pd.read_csv("https://archive.ics.uci.edu/static/public/365/data.csv")
#adding the data into a dataframe
polish_Dataset = pd.DataFrame(polishData)

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Set display width to avoid wrapping of wide DataFrames
pd.set_option('display.width', None)

# Set option to display full content of each column
pd.set_option('display.max_colwidth', None)
polish_Dataset.head(10)
# Out:
#    year        A1        A2        A3       A4        A5       A6        A7        A8       A9  \
# 0     1  0.200550  0.379510  0.396410   2.0472   32.3510  0.38825  0.249760   1.33050  1.13890
# 1     1  0.209120  0.499880  0.472250   1.9447   14.7860  0.00000  0.258340   0.99601  1.69960
# 2     1  0.248660  0.695920  0.267130   1.5548   -1.1523  0.00000  0.309060   0.43695  1.30900
# 3     1  0.081483  0.307340  0.458790   2.4928   51.9520  0.14988  0.092704   1.86610  1.05710
# 4     1  0.187320  0.613230  0.229600   1.4063   -7.3128  0.18732  0.187320   0.63070  1.15590
# 5     1  0.228220  0.497940  0.359690   1.7502  -47.7170  0.00000  0.281390   1.00830  1.97860
# 6     1  0.111090  0.647440  0.289710   1.4705    2.5349  0.00000  0.111090   0.54454  1.73480
# 7     1  0.532320  0.027059  0.705540  53.9540  299.5800  0.00000  0.652400  35.95700  0.65273
# 8     1  0.009020  0.632020  0.053735   1.1263  -37.8420  0.00000  0.014434   0.58223  1.33320
# 9     1  0.124080  0.838370  0.142040   1.1694  -91.8830  0.00000  0.153280   0.19279  2.11560
#
#        A10       A11        A12       A13       A14       A15        A16      A17       A18  \
# 0  0.50494  0.249760   0.659800  0.166600  0.249760   497.420   0.733780   2.6349  0.249760
# 1  0.49788  0.261140   0.516800  0.158350  0.258340   677.960   0.538380   2.0005  0.258340
# 2  0.30408  0.312580   0.641840  0.244350  0.309060   794.160   0.459610   1.4369  0.309060
# 3  0.57353  0.092704   0.301630  0.094257  0.092704   917.010   0.398030   3.2537  0.092704
# 4  0.38677  0.187320   0.331470  0.121820  0.187320  1133.200   0.322110   1.6307  0.187320
# 5  0.50206  0.286450   0.586910  0.148120  0.281390   620.140   0.588580   2.0083  0.281390
# 6  0.35256  0.125750   0.180410  0.309630  0.111090   439.940   0.829650   1.5445  0.111090
# 7  0.97294  0.693940  48.966000  1.060200  0.652400    14.272  25.575000  36.9570  0.652400
# 8  0.36798  0.043162   0.033921  0.038938  0.014434  4443.700   0.082138   1.5822  0.014434
# 9  0.16163  0.184540   0.182840  0.075411  0.153280  1918.100   0.190300   1.1928  0.153280
#
#         A19      A20      A21       A22       A23       A24      A25        A26       A27  \
# 0  0.149420   43.370  1.24790  0.214020  0.119980  0.477060  0.50494   0.604110   1.45820
# 1  0.152000   87.981  1.42930  0.248060  0.123040       NaN  0.39542   0.439920  88.44400
# 2  0.236100   73.133  1.42830  0.302600  0.189960       NaN  0.28932   0.372820  86.01100
# 3  0.071428   79.788  1.50690  0.115500  0.062782  0.171930  0.57353   0.361520   0.94076
# 4  0.115530   57.045      NaN  0.198320  0.115530  0.187320  0.38677   0.322110   1.41380
# 5  0.142220  107.260  1.72780  0.281040  0.115350       NaN  0.49970   0.481810  55.51100
# 6  0.064036   57.733  0.56811  0.000000  0.064036       NaN  0.31469   0.829650   0.00000
# 7  0.999490   39.978      NaN  0.671290  0.815530       NaN  0.96980  21.137000  16.15800
# 8  0.010827   36.623  1.07520  0.030778  0.006766  0.000222  0.34828   0.073572   1.07140
# 9  0.072451  109.970  1.58660  0.158190  0.058651       NaN  0.15445   0.155470   5.05920
#
#         A28     A29      A30       A31       A32      A33       A34       A35      A36       A37  \
# 0   1.76150  5.9443  0.11788  0.149420   94.1400   3.8772   0.56393  0.214020  1.74100  593.2700
# 1  16.94600  3.6884  0.26969  0.152000  122.1700   2.9876   2.98760  0.206160  1.69960       NaN
# 2   1.06270  4.3749  0.41929  0.238150  176.9300   2.0630   1.42740  0.315650  1.30900    2.3019
# 3   1.96180  4.6511  0.14343  0.071428   91.3700   3.9948   0.37581  0.115500  1.35620       NaN
# 4   1.11840  4.1424  0.27884  0.115530  147.0400   2.4823   0.32340  0.198320  1.62780   11.2470
# 5   2.23590  4.3258  0.23382  0.144490  102.7600   3.5519   3.42000  0.275660  1.97860   22.3120
# 6   3.06480  3.6770  0.36088  0.142230  328.7300   1.1103   1.05600  0.024982  1.73480       NaN
# 7   2.50960  4.2428 -0.67625  1.000300    8.1579  44.7420  22.03100  0.056612  0.65273   50.4300
# 8   0.10319  5.9479  0.47405  0.010827  142.0900   2.6284   1.76970  0.240130  1.33320    2.7538
# 9   7.22910  3.8430  0.38803  0.077401  157.1500   2.3226   2.32240  0.168540  2.11560       NaN
#
#        A38       A39        A40       A41       A42      A43       A44      A45       A46  \
# 0  0.50591  0.128040   0.662950  0.051402  0.128040  114.420   71.0500  1.00970   1.52250
# 1  0.49788  0.121300   0.086422  0.064371  0.145950  199.490  111.5100  0.51045   1.12520
# 2  0.51537  0.241140   0.322020  0.074020  0.231170  165.510   92.3810  0.94807   1.01010
# 3  0.57353  0.088995   0.401390  0.069622  0.088995  180.770  100.9800  0.28720   1.56960
# 4  0.43489  0.122310   0.293040  0.096680  0.122310  141.620   84.5740  0.73919   0.95787
# 5  0.51361  0.139320   0.078634  0.056701  0.142040  147.840   40.5780  0.39250   0.53744
# 6  0.35256  0.014400   0.056647  0.050653  0.000000  183.170  125.4400  0.40485   1.02490
# 7  0.98578  0.086730  47.991000  0.001269  1.028400   44.426    4.4485  7.44580  48.58800
# 8  0.49344  0.180110   0.072677  0.308650  0.023085  122.740   86.1220  0.06743   0.81192
# 9  0.16163  0.079665   0.020833  0.169940  0.074772  166.130   56.1590  0.19467   0.40912
#
#        A47       A48       A49       A50       A51      A52       A53      A54          A55  \
# 0   49.394  0.185300  0.110850   2.04200  0.378540  0.25792   2.24370   2.2480  348690.0000
# 1  100.130  0.237270  0.139610   1.94470  0.499880  0.33472  17.86600  17.8660    2304.6000
# 2   96.372  0.291810  0.222930   1.07580  0.481520  0.48474   1.20980   2.0504    6332.7000
# 3   84.344  0.085874  0.066165   2.49280  0.307340  0.25033   2.45240   2.4524   20545.0000
# 4   65.936  0.188110  0.116010   1.29590  0.565110  0.40285   1.88390   2.1184    3186.6000
# 5  124.630  0.269350  0.136130   1.68520  0.479440  0.28154   3.12090   3.1927    7616.8000
# 6  146.490 -0.426060 -0.245600   1.39850  0.615760  0.90064   3.72970   3.7297    1377.1000
# 7   43.774  0.631660  0.967720  26.56700  0.013323  0.02235   3.46070   3.5064   12341.0000
# 8   43.654 -0.006701 -0.005026   0.75832  0.425540  0.38046   0.70666   0.9476       1.1263
# 9  119.490  0.151920  0.071812   1.16940  0.838310  0.43056   8.22600   8.2260     989.4100
#
#         A56       A57      A58       A59     A60      A61       A62      A63       A64  class
# 0  0.121960  0.397180  0.87804  0.001924  8.4160   5.1372   82.6580   4.4158    7.4277      0
# 1  0.121300  0.420020  0.85300  0.000000  4.1486   3.2732  107.3500   3.4000   60.9870      0
# 2  0.241140  0.817740  0.76599  0.694840  4.9909   3.9510  134.2700   2.7185    5.2078      0
# 3  0.054015  0.142070  0.94598  0.000000  4.5746   3.6147   86.4350   4.2228    5.5497      0
# 4  0.134850  0.484310  0.86515  0.124440  6.3985   4.3158  127.2100   2.8692    7.8980      0
# 5  0.139320  0.454570  0.85891  0.023002  3.4028   8.9949   88.4440   4.1269   12.2990      0
# 6  0.605900  0.315100  0.40871  0.000000  6.3222   2.9098  129.5500   2.8173   18.3520      0
# 7  0.086730  0.547130  0.49521  0.013194  9.1300  82.0500    7.4503  48.9910    2.3217      0
# 8  0.180110  0.024512  0.84165  0.340940  9.9665   4.2382  116.5000   3.1330    2.5603      0
# 9  0.079665  0.767680  0.92847  0.000000  3.3192   6.4994  144.6300   2.5236  107.6700      0

# %%
#The orginal dataset did not have named columns. It provided an explantion to each attribute in their reserach paper. The code below is to add the proper names.
#replacing the column name with actual names.

new_Column_names={
    'A1':'net_profit/total assets',
    "A2":'Total_Liabilities/total_assets',
    "A3":'Working_Capital_to_Total_Assets_Ratio',
    "A4":'Current_Ratio',
    "A5":"Defensive_Interval_Ratio",
    "A6":'Retained_Earnings_to_Total_Assets_Ratio',
    "A7":"Operating_Income_to_Total_Asset_ratio",
    "A8":"book_value_of_equity/total_liabilities",
    "A9":'Asset_Turnover_Ratio',
    "A10":'Equity_to_Total_Assets_Ratio',
    "A11":'gross_profit+extraordinary_items+financial_expenses)/total',
    "A12":'gross_profit/short-term_liabilities',
    "A13":'(gross_profit+depreciation)/sales',
    "A14":'(gross_profit+interest)/total_assets',
    "A15":'(total_liabilities∗365)/(gross_profit+depreciation)',
    "A16":'(gross profit+depreciation)/total_liabilities',
    "A17":'total_assets/total_liabilities',
    "A18":'gross_profit/total_assets',
    "A19":'gross_profit/sales',
    "A20":'(inventory∗365)/sales',
    "A21":'sales(n)/sales(n-1)',
    "A22":'profit_on_operating_activities/total_assets',
    "A23":'net_profit/sales',
    "A24":'gross_profit(in3years)/total_assets',
    "A25":'(equity-share_capital)/total_assets',
    "A26":'(net_profit+depreciation)/total_liabilities',
    "A27":'profit_on_operating_activities/financial_expenses',
    "A28":'working_capital/fixed_assets',
    "A29":'logarithm_of_total_assets',
    "A30":'(total_liabilities-cash)/sales',
    "A31":'(gross_profit+interest)/sales',
    "A32":'(current_liabilities∗365)/cost_of_products_sold',
    "A33":'operating_expenses/short-term_liabilities',
    "A34":'operating_expenses_/_total_liabilities',
    "A35":'profit_on_sales/total_assets',
    "A36":'total_sales/total_assets',
    "A37":'(current_assets-inventories)/long-term_liabilities',
    "A38":'constant_capital/total_assets',
    "A39":'profit_on_sales/sales',
    "A40":'(current_assets-inventory-receivables)/short-term liabilities',
    "A41":'total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))',
    "A42":'profit_on_operating_activities/sales',
    "A43":'rotation_receivables+inventory_turnover_in_days',
    "A44":'(receivables∗365)/sales',
    "A45": 'net_profit/inventory',
    "A46":'(current_assets-inventory)/short-term_liabilities',
    "A47":'(inventory∗365)/cost_of_products_sold',
    "A48":'EBITDA_(profit_on_operating_activities-depreciation)/total_assets',
    "A49":'EBITDA_(profit_on_operating_activities-depreciation)/sales',
    "A50":'current_assets/total_liabilities',
    "A51":'short-term_liabilities/total_assets',
    "A52":'(short-term_liabilities∗365)/cost_of_products_sold)',
    "A53":'equity/fixed_assets',
    "A54":'constant_capital/fixed_assets',
    "A55":'working_capital',
    "A56":'(sales-cost_of_products_sold)/sales',
    "A57":'(current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)',
    "A58":'total_costs/total_sales',
    "A59":'long-term_liabilities/equity',
    "A60":'sales/inventory',
    "A61":'sales/receivables',
    "A62":'(short-term_liabilities∗365)/sales',
    "A63":'sales/short-term liabilities',
    "A64":'sales/fixed assets',
                          }

# %%
polish_Dataset =polish_Dataset.rename(columns=new_Column_names)

# %%
#based on the intial review of all the attributes type, it was noted that the class ratio was listed as int.
#making the class into a categorial data type from int
polish_Dataset['class']=polish_Dataset['class'].astype('category')

# %%
#snapshot of the features after change in data type 'class'
polish_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43405 entries, 0 to 43404
# Data columns (total 66 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   year                                                                                 43405 non-null  int64
#  1   net_profit/total assets                                                              43397 non-null  float64
#  2   Total_Liabilities/total_assets                                                       43397 non-null  float64
#  3   Working_Capital_to_Total_Assets_Ratio                                                43397 non-null  float64
#  4   Current_Ratio                                                                        43271 non-null  float64
#  5   Defensive_Interval_Ratio                                                             43316 non-null  float64
#  6   Retained_Earnings_to_Total_Assets_Ratio                                              43397 non-null  float64
#  7   Operating_Income_to_Total_Asset_ratio                                                43397 non-null  float64
#  8   book_value_of_equity/total_liabilities                                               43311 non-null  float64
#  9   Asset_Turnover_Ratio                                                                 43396 non-null  float64
#  10  Equity_to_Total_Assets_Ratio                                                         43397 non-null  float64
#  11  gross_profit+extraordinary_items+financial_expenses)/total                           43361 non-null  float64
#  12  gross_profit/short-term_liabilities                                                  43271 non-null  float64
#  13  (gross_profit+depreciation)/sales                                                    43278 non-null  float64
#  14  (gross_profit+interest)/total_assets                                                 43397 non-null  float64
#  15  (total_liabilities∗365)/(gross_profit+depreciation)                                  43369 non-null  float64
#  16  (gross profit+depreciation)/total_liabilities                                        43310 non-null  float64
#  17  total_assets/total_liabilities                                                       43311 non-null  float64
#  18  gross_profit/total_assets                                                            43397 non-null  float64
#  19  gross_profit/sales                                                                   43277 non-null  float64
#  20  (inventory∗365)/sales                                                                43278 non-null  float64
#  21  sales(n)/sales(n-1)                                                                  37551 non-null  float64
#  22  profit_on_operating_activities/total_assets                                          43397 non-null  float64
#  23  net_profit/sales                                                                     43278 non-null  float64
#  24  gross_profit(in3years)/total_assets                                                  42483 non-null  float64
#  25  (equity-share_capital)/total_assets                                                  43397 non-null  float64
#  26  (net_profit+depreciation)/total_liabilities                                          43310 non-null  float64
#  27  profit_on_operating_activities/financial_expenses                                    40641 non-null  float64
#  28  working_capital/fixed_assets                                                         42593 non-null  float64
#  29  logarithm_of_total_assets                                                            43397 non-null  float64
#  30  (total_liabilities-cash)/sales                                                       43278 non-null  float64
#  31  (gross_profit+interest)/sales                                                        43278 non-null  float64
#  32  (current_liabilities∗365)/cost_of_products_sold                                      43037 non-null  float64
#  33  operating_expenses/short-term_liabilities                                            43271 non-null  float64
#  34  operating_expenses_/_total_liabilities                                               43311 non-null  float64
#  35  profit_on_sales/total_assets                                                         43397 non-null  float64
#  36  total_sales/total_assets                                                             43397 non-null  float64
#  37  (current_assets-inventories)/long-term_liabilities                                   24421 non-null  float64
#  38  constant_capital/total_assets                                                        43397 non-null  float64
#  39  profit_on_sales/sales                                                                43278 non-null  float64
#  40  (current_assets-inventory-receivables)/short-term liabilities                        43271 non-null  float64
#  41  total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))           42651 non-null  float64
#  42  profit_on_operating_activities/sales                                                 43278 non-null  float64
#  43  rotation_receivables+inventory_turnover_in_days                                      43278 non-null  float64
#  44  (receivables∗365)/sales                                                              43278 non-null  float64
#  45  net_profit/inventory                                                                 41258 non-null  float64
#  46  (current_assets-inventory)/short-term_liabilities                                    43270 non-null  float64
#  47  (inventory∗365)/cost_of_products_sold                                                43108 non-null  float64
#  48  EBITDA_(profit_on_operating_activities-depreciation)/total_assets                    43396 non-null  float64
#  49  EBITDA_(profit_on_operating_activities-depreciation)/sales                           43278 non-null  float64
#  50  current_assets/total_liabilities                                                     43311 non-null  float64
#  51  short-term_liabilities/total_assets                                                  43397 non-null  float64
#  52  (short-term_liabilities∗365)/cost_of_products_sold)                                  43104 non-null  float64
#  53  equity/fixed_assets                                                                  42593 non-null  float64
#  54  constant_capital/fixed_assets                                                        42593 non-null  float64
#  55  working_capital                                                                      43404 non-null  float64
#  56  (sales-cost_of_products_sold)/sales                                                  43278 non-null  float64
#  57  (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)  43398 non-null  float64
#  58  total_costs/total_sales                                                              43321 non-null  float64
#  59  long-term_liabilities/equity                                                         43398 non-null  float64
#  60  sales/inventory                                                                      41253 non-null  float64
#  61  sales/receivables                                                                    43303 non-null  float64
#  62  (short-term_liabilities∗365)/sales                                                   43278 non-null  float64
#  63  sales/short-term liabilities                                                         43271 non-null  float64
#  64  sales/fixed assets                                                                   42593 non-null  float64
#  65  class                                                                                43405 non-null  category
# dtypes: category(1), float64(64), int64(1)
# memory usage: 21.6 MB

# %% [markdown]
# #Variable Additions
# This research paper was to introduce financial ratios that can help identify financial stress. This analysis was done by reviewing all attributes and seeing what can be added.
#
# The following additions are based on using exisitng variables to create these additions. This is based on existing and industry knowledge.

# %%
#The introduction of this variable is to get an understanding of how much of interest paid is to sales.
#A high proportion of interest to sales will indicate that a good portion of their sales earned will go towards paying the interest and other cost may not be covered.
#Variable 1
Interest_to_Sales = (polish_Dataset['(gross_profit+interest)/sales']-polish_Dataset['gross_profit/sales'])
Interest_to_Sales.replace([np.inf, -np.inf], np.NaN, inplace=True )
Interest_to_Sales
polish_Dataset['Interest_to_Sales'] = Interest_to_Sales

# %%
#To gain an understanding on liquidity compared to all assets. Cash is the most liquid asset and can be
#used to cover debt/interest in the short term.
#variable 2
Cash_to_assets  = (polish_Dataset['Total_Liabilities/total_assets']-(polish_Dataset['(total_liabilities-cash)/sales'] * polish_Dataset['total_sales/total_assets'] ))
Cash_to_assets.replace([np.inf, -np.inf], np.NaN, inplace=True )
Cash_to_assets
polish_Dataset['Cash_to_assets'] = Cash_to_assets

# %%
#This is to gain an understanding on how much cash can cover total liabilities. Too high can tell us that the company may have a hard time covering their liabilities.
#variable 3
Total_liabilities_to_Cash = (polish_Dataset['Total_Liabilities/total_assets']/ polish_Dataset['Cash_to_assets'] )
Total_liabilities_to_Cash.replace([np.inf, -np.inf], np.NaN, inplace=True )
Total_liabilities_to_Cash
polish_Dataset['Total_liabilities_to_Cash'] = Total_liabilities_to_Cash

# %%
#Tells us how much interest can be covered by cash. A high number gives comfort that the company can cover their interest obligations
#variable 4
cash_to_interest = (polish_Dataset['Cash_to_assets']/ polish_Dataset['total_sales/total_assets'] * (1/polish_Dataset['Interest_to_Sales']))
cash_to_interest.replace([np.inf, -np.inf], np.NaN, inplace=True )
cash_to_interest
polish_Dataset['cash_to_interest'] = cash_to_interest

# %%
#After initial analysis, I realized that not all companies have debt/paid interest during their fiscal year.
#This is ratio is taking the inverse.
#variable 5
Interest_to_cash = 1 /(polish_Dataset['cash_to_interest'])
Interest_to_cash.replace([np.inf, -np.inf], np.NaN, inplace=True )
Interest_to_cash
polish_Dataset['Interest_to_cash'] = Interest_to_cash

# %%
#This ratio to review how much financial expense is covered by total assets. a high number indicates to me that the company has taken on too much debt and may find trouble as assets
#may not be enough relative to debt. this ratio can be used with asset turnover to provide more direction.
#variable 6
Financial_Expense_To_Total_Asset = (polish_Dataset['profit_on_operating_activities/total_assets'] / polish_Dataset['profit_on_operating_activities/financial_expenses'])
Financial_Expense_To_Total_Asset.replace([np.inf, -np.inf], np.NaN, inplace=True )
Financial_Expense_To_Total_Asset
polish_Dataset['Financial_Expense_To_Total_Asset'] = Financial_Expense_To_Total_Asset

# %%
#variable 6
Financial_expense_to_operating = (polish_Dataset['profit_on_operating_activities/total_assets'] / (polish_Dataset["Operating_Income_to_Total_Asset_ratio"]*polish_Dataset['profit_on_operating_activities/financial_expenses']))
Financial_expense_to_operating.replace([np.inf, -np.inf], np.NaN, inplace=True )
Financial_expense_to_operating
polish_Dataset['Financial_expense_to_operating']=Financial_expense_to_operating

# %%
#this ratio gives me an idea on how much operating income can cover the interst for the fiscal period. a high ratio is a good indicator.
#variable 7
Debt_Coverage_Ratio = ((polish_Dataset["Operating_Income_to_Total_Asset_ratio"]*polish_Dataset['profit_on_operating_activities/financial_expenses']) / polish_Dataset['profit_on_operating_activities/total_assets'])
Debt_Coverage_Ratio.replace([np.inf, -np.inf], np.NaN, inplace=True )
Debt_Coverage_Ratio
polish_Dataset['Debt_Coverage_Ratio'] = Debt_Coverage_Ratio

# %%
#operating income can be viewed as cash flow from operating. it it not however, but in its place it can give the reader an idea.
#THis give us the percentage that is avaiable to firm after all expenses are paid from sales for the fiscal
#variable 8
Operating_income_Margin = (polish_Dataset['Operating_Income_to_Total_Asset_ratio'] / polish_Dataset['total_sales/total_assets'])
Operating_income_Margin.replace([np.inf, -np.inf], np.NaN, inplace=True )
Operating_income_Margin
polish_Dataset['Operating_income_Margin'] = Operating_income_Margin

# %%
#this ratio tells us how many days  cash is recieved from the momement it is used to pay for inventory and accounts payble, as well as cash recieved from buyers. The lower the number the better
#Variable 9 Cash Conversion Cycle Formula = DIO + DSO – DPO.
Cash_conversion_cycle = ((polish_Dataset['(inventory∗365)/cost_of_products_sold']) + (polish_Dataset['(receivables∗365)/sales']) - (polish_Dataset['(short-term_liabilities∗365)/cost_of_products_sold)']))
Cash_conversion_cycle.replace([np.inf, -np.inf], np.NaN, inplace=True )
Cash_conversion_cycle
polish_Dataset['Cash_conversion_cycle'] = Cash_conversion_cycle

# %%
#This ratio is used to determine how much cash can be used to cover financial expense. since cash is the most liquid asset, a high number indicates
#the ability to cover financial expenses
#variable 10
Cash_to_Financial_expense = (polish_Dataset['Cash_to_assets'] / polish_Dataset['Financial_Expense_To_Total_Asset'])
Cash_to_Financial_expense.replace([np.inf, -np.inf], np.NaN, inplace=True )
polish_Dataset['Cash_to_Financial_Expense']= Cash_to_Financial_expense

# %%
#Used as part of the dupont formula (i.e Return on equity), gives us indication how much leverage is used.

#variable 11
Equity_multipler= 1/ polish_Dataset['Equity_to_Total_Assets_Ratio']
Equity_multipler.replace([np.inf, -np.inf], np.NaN, inplace=True )
polish_Dataset['Financial_Leverage'] = Equity_multipler

# %%
#not addition but transforming an existing attribute to 1,0. if working capital is postive, it will be given a 1, if negative it will given a 0.
#making working capital into a indicator. 1 = postive values, 0 = negative
polish_Dataset['working_capital_indicator'] =np.where(polish_Dataset['working_capital']<=0,0,1)
polish_Dataset['working_capital_indicator']=polish_Dataset['working_capital_indicator'].astype('category')

# %%
#final ratio is return on equity. this is to gauge on management perfromance on how much they retun to shareholders.
#since this ratio is the result of the dupoint formula, it helps us determine what goes into the results for shareholders. such as
#asset turnover and financial leverage. a high financial leverage tell us that the results are coming from debt.
#Variable12
Return_On_equity =polish_Dataset['net_profit/sales'] * polish_Dataset['total_sales/total_assets'] *polish_Dataset['Financial_Leverage']
Return_On_equity.replace([np.inf, -np.inf], np.NaN, inplace=True )
polish_Dataset['Return_On_equity'] = Return_On_equity

# %%
#Review of all financial ratios in the polish dataset
polish_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43405 entries, 0 to 43404
# Data columns (total 80 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   year                                                                                 43405 non-null  int64
#  1   net_profit/total assets                                                              43397 non-null  float64
#  2   Total_Liabilities/total_assets                                                       43397 non-null  float64
#  3   Working_Capital_to_Total_Assets_Ratio                                                43397 non-null  float64
#  4   Current_Ratio                                                                        43271 non-null  float64
#  5   Defensive_Interval_Ratio                                                             43316 non-null  float64
#  6   Retained_Earnings_to_Total_Assets_Ratio                                              43397 non-null  float64
#  7   Operating_Income_to_Total_Asset_ratio                                                43397 non-null  float64
#  8   book_value_of_equity/total_liabilities                                               43311 non-null  float64
#  9   Asset_Turnover_Ratio                                                                 43396 non-null  float64
#  10  Equity_to_Total_Assets_Ratio                                                         43397 non-null  float64
#  11  gross_profit+extraordinary_items+financial_expenses)/total                           43361 non-null  float64
#  12  gross_profit/short-term_liabilities                                                  43271 non-null  float64
#  13  (gross_profit+depreciation)/sales                                                    43278 non-null  float64
#  14  (gross_profit+interest)/total_assets                                                 43397 non-null  float64
#  15  (total_liabilities∗365)/(gross_profit+depreciation)                                  43369 non-null  float64
#  16  (gross profit+depreciation)/total_liabilities                                        43310 non-null  float64
#  17  total_assets/total_liabilities                                                       43311 non-null  float64
#  18  gross_profit/total_assets                                                            43397 non-null  float64
#  19  gross_profit/sales                                                                   43277 non-null  float64
#  20  (inventory∗365)/sales                                                                43278 non-null  float64
#  21  sales(n)/sales(n-1)                                                                  37551 non-null  float64
#  22  profit_on_operating_activities/total_assets                                          43397 non-null  float64
#  23  net_profit/sales                                                                     43278 non-null  float64
#  24  gross_profit(in3years)/total_assets                                                  42483 non-null  float64
#  25  (equity-share_capital)/total_assets                                                  43397 non-null  float64
#  26  (net_profit+depreciation)/total_liabilities                                          43310 non-null  float64
#  27  profit_on_operating_activities/financial_expenses                                    40641 non-null  float64
#  28  working_capital/fixed_assets                                                         42593 non-null  float64
#  29  logarithm_of_total_assets                                                            43397 non-null  float64
#  30  (total_liabilities-cash)/sales                                                       43278 non-null  float64
#  31  (gross_profit+interest)/sales                                                        43278 non-null  float64
#  32  (current_liabilities∗365)/cost_of_products_sold                                      43037 non-null  float64
#  33  operating_expenses/short-term_liabilities                                            43271 non-null  float64
#  34  operating_expenses_/_total_liabilities                                               43311 non-null  float64
#  35  profit_on_sales/total_assets                                                         43397 non-null  float64
#  36  total_sales/total_assets                                                             43397 non-null  float64
#  37  (current_assets-inventories)/long-term_liabilities                                   24421 non-null  float64
#  38  constant_capital/total_assets                                                        43397 non-null  float64
#  39  profit_on_sales/sales                                                                43278 non-null  float64
#  40  (current_assets-inventory-receivables)/short-term liabilities                        43271 non-null  float64
#  41  total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))           42651 non-null  float64
#  42  profit_on_operating_activities/sales                                                 43278 non-null  float64
#  43  rotation_receivables+inventory_turnover_in_days                                      43278 non-null  float64
#  44  (receivables∗365)/sales                                                              43278 non-null  float64
#  45  net_profit/inventory                                                                 41258 non-null  float64
#  46  (current_assets-inventory)/short-term_liabilities                                    43270 non-null  float64
#  47  (inventory∗365)/cost_of_products_sold                                                43108 non-null  float64
#  48  EBITDA_(profit_on_operating_activities-depreciation)/total_assets                    43396 non-null  float64
#  49  EBITDA_(profit_on_operating_activities-depreciation)/sales                           43278 non-null  float64
#  50  current_assets/total_liabilities                                                     43311 non-null  float64
#  51  short-term_liabilities/total_assets                                                  43397 non-null  float64
#  52  (short-term_liabilities∗365)/cost_of_products_sold)                                  43104 non-null  float64
#  53  equity/fixed_assets                                                                  42593 non-null  float64
#  54  constant_capital/fixed_assets                                                        42593 non-null  float64
#  55  working_capital                                                                      43404 non-null  float64
#  56  (sales-cost_of_products_sold)/sales                                                  43278 non-null  float64
#  57  (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)  43398 non-null  float64
#  58  total_costs/total_sales                                                              43321 non-null  float64
#  59  long-term_liabilities/equity                                                         43398 non-null  float64
#  60  sales/inventory                                                                      41253 non-null  float64
#  61  sales/receivables                                                                    43303 non-null  float64
#  62  (short-term_liabilities∗365)/sales                                                   43278 non-null  float64
#  63  sales/short-term liabilities                                                         43271 non-null  float64
#  64  sales/fixed assets                                                                   42593 non-null  float64
#  65  class                                                                                43405 non-null  category
#  66  Interest_to_Sales                                                                    43277 non-null  float64
#  67  Cash_to_assets                                                                       43270 non-null  float64
#  68  Total_liabilities_to_Cash                                                            43238 non-null  float64
#  69  cash_to_interest                                                                     23529 non-null  float64
#  70  Interest_to_cash                                                                     23511 non-null  float64
#  71  Financial_Expense_To_Total_Asset                                                     37664 non-null  float64
#  72  Financial_expense_to_operating                                                       37635 non-null  float64
#  73  Debt_Coverage_Ratio                                                                  37652 non-null  float64
#  74  Operating_income_Margin                                                              43321 non-null  float64
#  75  Cash_conversion_cycle                                                                42986 non-null  float64
#  76  Cash_to_Financial_Expense                                                            37567 non-null  float64
#  77  Financial_Leverage                                                                   43393 non-null  float64
#  78  working_capital_indicator                                                            43405 non-null  category
#  79  Return_On_equity                                                                     43266 non-null  float64
# dtypes: category(2), float64(77), int64(1)
# memory usage: 25.9 MB

# %%
polish_Dataset.head()
# Out:
#    year  net_profit/total assets  Total_Liabilities/total_assets  \
# 0     1                 0.200550                         0.37951
# 1     1                 0.209120                         0.49988
# 2     1                 0.248660                         0.69592
# 3     1                 0.081483                         0.30734
# 4     1                 0.187320                         0.61323
#
#    Working_Capital_to_Total_Assets_Ratio  Current_Ratio  Defensive_Interval_Ratio  \
# 0                                0.39641         2.0472                   32.3510
# 1                                0.47225         1.9447                   14.7860
# 2                                0.26713         1.5548                   -1.1523
# 3                                0.45879         2.4928                   51.9520
# 4                                0.22960         1.4063                   -7.3128
#
#    Retained_Earnings_to_Total_Assets_Ratio  Operating_Income_to_Total_Asset_ratio  \
# 0                                  0.38825                               0.249760
# 1                                  0.00000                               0.258340
# 2                                  0.00000                               0.309060
# 3                                  0.14988                               0.092704
# 4                                  0.18732                               0.187320
#
#    book_value_of_equity/total_liabilities  Asset_Turnover_Ratio  Equity_to_Total_Assets_Ratio  \
# 0                                 1.33050                1.1389                       0.50494
# 1                                 0.99601                1.6996                       0.49788
# 2                                 0.43695                1.3090                       0.30408
# 3                                 1.86610                1.0571                       0.57353
# 4                                 0.63070                1.1559                       0.38677
#
#    gross_profit+extraordinary_items+financial_expenses)/total  \
# 0                                                    0.249760
# 1                                                    0.261140
# 2                                                    0.312580
# 3                                                    0.092704
# 4                                                    0.187320
#
#    gross_profit/short-term_liabilities  (gross_profit+depreciation)/sales  \
# 0                              0.65980                           0.166600
# 1                              0.51680                           0.158350
# 2                              0.64184                           0.244350
# 3                              0.30163                           0.094257
# 4                              0.33147                           0.121820
#
#    (gross_profit+interest)/total_assets  (total_liabilities∗365)/(gross_profit+depreciation)  \
# 0                              0.249760                                               497.42
# 1                              0.258340                                               677.96
# 2                              0.309060                                               794.16
# 3                              0.092704                                               917.01
# 4                              0.187320                                              1133.20
#
#    (gross profit+depreciation)/total_liabilities  total_assets/total_liabilities  \
# 0                                        0.73378                          2.6349
# 1                                        0.53838                          2.0005
# 2                                        0.45961                          1.4369
# 3                                        0.39803                          3.2537
# 4                                        0.32211                          1.6307
#
#    gross_profit/total_assets  gross_profit/sales  (inventory∗365)/sales  sales(n)/sales(n-1)  \
# 0                   0.249760            0.149420                 43.370               1.2479
# 1                   0.258340            0.152000                 87.981               1.4293
# 2                   0.309060            0.236100                 73.133               1.4283
# 3                   0.092704            0.071428                 79.788               1.5069
# 4                   0.187320            0.115530                 57.045                  NaN
#
#    profit_on_operating_activities/total_assets  net_profit/sales  \
# 0                                      0.21402          0.119980
# 1                                      0.24806          0.123040
# 2                                      0.30260          0.189960
# 3                                      0.11550          0.062782
# 4                                      0.19832          0.115530
#
#    gross_profit(in3years)/total_assets  (equity-share_capital)/total_assets  \
# 0                              0.47706                              0.50494
# 1                                  NaN                              0.39542
# 2                                  NaN                              0.28932
# 3                              0.17193                              0.57353
# 4                              0.18732                              0.38677
#
#    (net_profit+depreciation)/total_liabilities  profit_on_operating_activities/financial_expenses  \
# 0                                      0.60411                                            1.45820
# 1                                      0.43992                                           88.44400
# 2                                      0.37282                                           86.01100
# 3                                      0.36152                                            0.94076
# 4                                      0.32211                                            1.41380
#
#    working_capital/fixed_assets  logarithm_of_total_assets  (total_liabilities-cash)/sales  \
# 0                        1.7615                     5.9443                         0.11788
# 1                       16.9460                     3.6884                         0.26969
# 2                        1.0627                     4.3749                         0.41929
# 3                        1.9618                     4.6511                         0.14343
# 4                        1.1184                     4.1424                         0.27884
#
#    (gross_profit+interest)/sales  (current_liabilities∗365)/cost_of_products_sold  \
# 0                       0.149420                                            94.14
# 1                       0.152000                                           122.17
# 2                       0.238150                                           176.93
# 3                       0.071428                                            91.37
# 4                       0.115530                                           147.04
#
#    operating_expenses/short-term_liabilities  operating_expenses_/_total_liabilities  \
# 0                                     3.8772                                 0.56393
# 1                                     2.9876                                 2.98760
# 2                                     2.0630                                 1.42740
# 3                                     3.9948                                 0.37581
# 4                                     2.4823                                 0.32340
#
#    profit_on_sales/total_assets  total_sales/total_assets  \
# 0                       0.21402                    1.7410
# 1                       0.20616                    1.6996
# 2                       0.31565                    1.3090
# 3                       0.11550                    1.3562
# 4                       0.19832                    1.6278
#
#    (current_assets-inventories)/long-term_liabilities  constant_capital/total_assets  \
# 0                                            593.2700                        0.50591
# 1                                                 NaN                        0.49788
# 2                                              2.3019                        0.51537
# 3                                                 NaN                        0.57353
# 4                                             11.2470                        0.43489
#
#    profit_on_sales/sales  (current_assets-inventory-receivables)/short-term liabilities  \
# 0               0.128040                                                       0.662950
# 1               0.121300                                                       0.086422
# 2               0.241140                                                       0.322020
# 3               0.088995                                                       0.401390
# 4               0.122310                                                       0.293040
#
#    total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))  \
# 0                                                                    0.051402
# 1                                                                    0.064371
# 2                                                                    0.074020
# 3                                                                    0.069622
# 4                                                                    0.096680
#
#    profit_on_operating_activities/sales  rotation_receivables+inventory_turnover_in_days  \
# 0                              0.128040                                           114.42
# 1                              0.145950                                           199.49
# 2                              0.231170                                           165.51
# 3                              0.088995                                           180.77
# 4                              0.122310                                           141.62
#
#    (receivables∗365)/sales  net_profit/inventory  \
# 0                   71.050               1.00970
# 1                  111.510               0.51045
# 2                   92.381               0.94807
# 3                  100.980               0.28720
# 4                   84.574               0.73919
#
#    (current_assets-inventory)/short-term_liabilities  (inventory∗365)/cost_of_products_sold  \
# 0                                            1.52250                                 49.394
# 1                                            1.12520                                100.130
# 2                                            1.01010                                 96.372
# 3                                            1.56960                                 84.344
# 4                                            0.95787                                 65.936
#
#    EBITDA_(profit_on_operating_activities-depreciation)/total_assets  \
# 0                                                           0.185300
# 1                                                           0.237270
# 2                                                           0.291810
# 3                                                           0.085874
# 4                                                           0.188110
#
#    EBITDA_(profit_on_operating_activities-depreciation)/sales  current_assets/total_liabilities  \
# 0                                                    0.110850                            2.0420
# 1                                                    0.139610                            1.9447
# 2                                                    0.222930                            1.0758
# 3                                                    0.066165                            2.4928
# 4                                                    0.116010                            1.2959
#
#    short-term_liabilities/total_assets  (short-term_liabilities∗365)/cost_of_products_sold)  \
# 0                              0.37854                                              0.25792
# 1                              0.49988                                              0.33472
# 2                              0.48152                                              0.48474
# 3                              0.30734                                              0.25033
# 4                              0.56511                                              0.40285
#
#    equity/fixed_assets  constant_capital/fixed_assets  working_capital  \
# 0               2.2437                         2.2480         348690.0
# 1              17.8660                        17.8660           2304.6
# 2               1.2098                         2.0504           6332.7
# 3               2.4524                         2.4524          20545.0
# 4               1.8839                         2.1184           3186.6
#
#    (sales-cost_of_products_sold)/sales  \
# 0                             0.121960
# 1                             0.121300
# 2                             0.241140
# 3                             0.054015
# 4                             0.134850
#
#    (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)  \
# 0                                                                              0.39718
# 1                                                                              0.42002
# 2                                                                              0.81774
# 3                                                                              0.14207
# 4                                                                              0.48431
#
#    total_costs/total_sales  long-term_liabilities/equity  sales/inventory  sales/receivables  \
# 0                  0.87804                      0.001924           8.4160             5.1372
# 1                  0.85300                      0.000000           4.1486             3.2732
# 2                  0.76599                      0.694840           4.9909             3.9510
# 3                  0.94598                      0.000000           4.5746             3.6147
# 4                  0.86515                      0.124440           6.3985             4.3158
#
#    (short-term_liabilities∗365)/sales  sales/short-term liabilities  sales/fixed assets class  \
# 0                              82.658                        4.4158              7.4277     0
# 1                             107.350                        3.4000             60.9870     0
# 2                             134.270                        2.7185              5.2078     0
# 3                              86.435                        4.2228              5.5497     0
# 4                             127.210                        2.8692              7.8980     0
#
#    Interest_to_Sales  Cash_to_assets  Total_liabilities_to_Cash  cash_to_interest  \
# 0            0.00000        0.174281                   2.177576               NaN
# 1            0.00000        0.041515                  12.040985               NaN
# 2            0.00205        0.147069                   4.731916         54.806085
# 3            0.00000        0.112820                   2.724157               NaN
# 4            0.00000        0.159334                   3.848702               NaN
#
#    Interest_to_cash  Financial_Expense_To_Total_Asset  Financial_expense_to_operating  \
# 0               NaN                          0.146770                        0.587644
# 1               NaN                          0.002805                        0.010857
# 2          0.018246                          0.003518                        0.011383
# 3               NaN                          0.122773                        1.324356
# 4               NaN                          0.140274                        0.748849
#
#    Debt_Coverage_Ratio  Operating_income_Margin  Cash_conversion_cycle  Cash_to_Financial_Expense  \
# 0             1.701710                 0.143458              120.18608                   1.187442
# 1            92.109260                 0.152000              211.30528                  14.801829
# 2            87.847190                 0.236104              188.26826                  41.802992
# 3             0.755084                 0.068356              185.07367                   0.918933
# 4             1.335382                 0.115076              150.10715                   1.135875
#
#    Financial_Leverage working_capital_indicator  Return_On_equity
# 0            1.980433                         1          0.413683
# 1            2.008516                         1          0.420018
# 2            3.288608                         1          0.817738
# 3            1.743588                         1          0.148458
# 4            2.585516                         1          0.486231

# %%
polish_Dataset.tail()
# Out:
#        year  net_profit/total assets  Total_Liabilities/total_assets  \
# 43400     5                 0.012898                         0.70621
# 43401     5                -0.578050                         0.96702
# 43402     5                -0.179050                         1.25530
# 43403     5                -0.108860                         0.74394
# 43404     5                -0.105370                         0.53629
#
#        Working_Capital_to_Total_Assets_Ratio  Current_Ratio  Defensive_Interval_Ratio  \
# 43400                               0.038857        1.17220                   -18.907
# 43401                              -0.800850        0.16576                   -67.365
# 43402                              -0.275990        0.74554                  -120.440
# 43403                               0.015449        1.08780                   -17.003
# 43404                              -0.045578        0.91478                   -56.068
#
#        Retained_Earnings_to_Total_Assets_Ratio  Operating_Income_to_Total_Asset_ratio  \
# 43400                                  0.00000                               0.013981
# 43401                                 -0.57805                              -0.578050
# 43402                                 -0.17905                              -0.154930
# 43403                                 -0.10886                              -0.109180
# 43404                                 -0.10537                              -0.109940
#
#        book_value_of_equity/total_liabilities  Asset_Turnover_Ratio  Equity_to_Total_Assets_Ratio  \
# 43400                                 0.41600               1.67680                      0.293790
# 43401                                -0.40334               0.93979                     -0.390040
# 43402                                -0.26018               1.17490                     -0.326590
# 43403                                 0.12531               0.84516                      0.093224
# 43404                                 0.86460               0.95040                      0.463670
#
#        gross_profit+extraordinary_items+financial_expenses)/total  \
# 43400                                                    0.041583
# 43401                                                   -0.578050
# 43402                                                   -0.154930
# 43403                                                   -0.109180
# 43404                                                   -0.109940
#
#        gross_profit/short-term_liabilities  (gross_profit+depreciation)/sales  \
# 43400                             0.061959                           0.023622
# 43401                            -0.602160                          -0.110220
# 43402                            -0.142840                          -0.072940
# 43403                            -0.620380                          -0.065652
# 43404                            -0.205570                          -0.066747
#
#        (gross_profit+interest)/total_assets  (total_liabilities∗365)/(gross_profit+depreciation)  \
# 43400                              0.013981                                              6507.60
# 43401                             -0.578050                                              -742.28
# 43402                             -0.154930                                             -3298.20
# 43403                             -0.109180                                             -5352.10
# 43404                             -0.109940                                             -2055.90
#
#        (gross profit+depreciation)/total_liabilities  total_assets/total_liabilities  \
# 43400                                       0.056089                         1.41600
# 43401                                      -0.491730                         1.03410
# 43402                                      -0.110670                         0.79665
# 43403                                      -0.068197                         1.34420
# 43404                                      -0.177540                         1.86470
#
#        gross_profit/total_assets  gross_profit/sales  (inventory∗365)/sales  sales(n)/sales(n-1)  \
# 43400                   0.013981            0.008338                27.0920              1.03300
# 43401                  -0.578050           -0.133990                 3.2965              0.64770
# 43402                  -0.154930           -0.081350                37.0460              0.83104
# 43403                  -0.109180           -0.141280                26.2850              1.12100
# 43404                  -0.109940           -0.077072                47.1990              0.71351
#
#        profit_on_operating_activities/total_assets  net_profit/sales  \
# 43400                                     0.040401          0.007692
# 43401                                    -0.534920         -0.133990
# 43402                                     0.176700         -0.094015
# 43403                                    -0.099950         -0.140860
# 43404                                    -0.082947         -0.073868
#
#        gross_profit(in3years)/total_assets  (equity-share_capital)/total_assets  \
# 43400                              0.90184                             0.083706
# 43401                             -0.57805                            -0.390040
# 43402                             -0.15493                            -0.326590
# 43403                             -0.10918                             0.093224
# 43404                             -0.10994                             0.463670
#
#        (net_profit+depreciation)/total_liabilities  \
# 43400                                     0.054556
# 43401                                    -0.491730
# 43402                                    -0.129880
# 43403                                    -0.067762
# 43404                                    -0.169020
#
#        profit_on_operating_activities/financial_expenses  working_capital/fixed_assets  \
# 43400                                             1.4637                      0.052831
# 43401                                                NaN                     -0.952400
# 43402                                                NaN                     -1.442300
# 43403                                                NaN                      0.019106
# 43404                                                NaN                     -0.089234
#
#        logarithm_of_total_assets  (total_liabilities-cash)/sales  (gross_profit+interest)/sales  \
# 43400                     4.9667                         0.41853                       0.024762
# 43401                     4.0622                         0.21864                      -0.133990
# 43402                     5.3244                         0.65813                      -0.081350
# 43403                     4.8555                         0.95181                      -0.141280
# 43404                     3.9698                         0.37528                      -0.077072
#
#        (current_liabilities∗365)/cost_of_products_sold  operating_expenses/short-term_liabilities  \
# 43400                                           50.128                                     7.4000
# 43401                                           76.330                                     4.7819
# 43402                                          244.230                                     1.4945
# 43403                                           70.252                                     5.1956
# 43404                                          130.060                                     2.8064
#
#        operating_expenses_/_total_liabilities  profit_on_sales/total_assets  \
# 43400                                 2.36440                      0.033819
# 43401                                -0.55316                     -0.534920
# 43402                                 0.14077                      0.176700
# 43403                                -0.13435                     -0.099950
# 43404                                -0.15467                     -0.082947
#
#        total_sales/total_assets  (current_assets-inventories)/long-term_liabilities  \
# 43400                   1.67680                                             0.37850
# 43401                   4.39120                                            17.03600
# 43402                   1.95150                                             3.60650
# 43403                   0.83553                                             0.23908
# 43404                   1.44810                                           205.69000
#
#        constant_capital/total_assets  profit_on_sales/sales  \
# 43400                        0.66377               0.020169
# 43401                       -0.38299              -0.123990
# 43402                       -0.15597               0.092780
# 43403                        0.66118              -0.129340
# 43404                        0.46515              -0.058149
#
#        (current_assets-inventory-receivables)/short-term liabilities  \
# 43400                                                       0.022858
# 43401                                                       0.024771
# 43402                                                       0.064095
# 43403                                                       0.048976
# 43404                                                       0.004456
#
#        total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))  \
# 43400                                                                    0.356510
# 43401                                                                   -0.073529
# 43402                                                                    0.214140
# 43403                                                                   -0.589300
# 43404                                                                   -0.258460
#
#        profit_on_operating_activities/sales  rotation_receivables+inventory_turnover_in_days  \
# 43400                              0.024093                                           56.452
# 43401                             -0.123990                                           11.451
# 43402                              0.092780                                          141.650
# 43403                             -0.129340                                           86.348
# 43404                             -0.058149                                          124.570
#
#        (receivables∗365)/sales  net_profit/inventory  \
# 43400                  29.3600               0.10363
# 43401                   8.1548             -14.83600
# 43402                 104.6100              -0.92630
# 43403                  60.0640              -1.95610
# 43404                  77.3740              -0.57124
#
#        (current_assets-inventory)/short-term_liabilities  (inventory∗365)/cost_of_products_sold  \
# 43400                                            0.62061                                 27.207
# 43401                                            0.12517                                  3.098
# 43402                                            0.56733                                 43.526
# 43403                                            0.77157                                 22.215
# 43404                                            0.56987                                 44.858
#
#        EBITDA_(profit_on_operating_activities-depreciation)/total_assets  \
# 43400                                                           0.014771
# 43401                                                          -0.637460
# 43402                                                           0.160680
# 43403                                                          -0.158400
# 43404                                                          -0.097675
#
#        EBITDA_(profit_on_operating_activities-depreciation)/sales  \
# 43400                                                    0.008809
# 43401                                                   -0.147760
# 43402                                                    0.084370
# 43403                                                   -0.204970
# 43404                                                   -0.068474
#
#        current_assets/total_liabilities  short-term_liabilities/total_assets  \
# 43400                           0.37454                              0.22564
# 43401                           0.16455                              0.95997
# 43402                           0.64421                              1.08460
# 43403                           0.25733                              0.17599
# 43404                           0.91225                              0.53481
#
#        (short-term_liabilities∗365)/cost_of_products_sold)  equity/fixed_assets  \
# 43400                                              0.13514              0.39944
# 43401                                              0.20912             -0.46385
# 43402                                              0.66913             -1.70670
# 43403                                              0.19247              0.11530
# 43404                                              0.35632              0.90779
#
#        constant_capital/fixed_assets  working_capital  (sales-cost_of_products_sold)/sales  \
# 43400                        0.90248          3599.10                             0.020169
# 43401                       -0.45546         -9242.10                            -0.064073
# 43402                       -0.81508        -58253.00                             0.148880
# 43403                        0.81772          1107.50                            -0.183200
# 43404                        0.91069          -425.13                            -0.052186
#
#        (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)  \
# 43400                                                                             0.043904
# 43401                                                                             1.482000
# 43402                                                                             0.548240
# 43403                                                                            -1.167700
# 43404                                                                            -0.227250
#
#        total_costs/total_sales  long-term_liabilities/equity  sales/inventory  sales/receivables  \
# 43400                  1.01220                      1.259400          13.4720            12.4320
# 43401                  1.06410                     -0.018084         110.7200            44.7590
# 43402                  0.85112                     -0.522430           9.8526             3.4892
# 43403                  1.18320                      6.092400          13.8860             6.0769
# 43404                  1.05220                      0.003196           7.7332             4.7174
#
#        (short-term_liabilities∗365)/sales  sales/short-term liabilities  sales/fixed assets class  \
# 43400                              49.117                        7.4313             2.27990     1
# 43401                              81.220                        4.4940             5.13050     1
# 43402                             207.870                        1.7559             9.95270     1
# 43403                              83.122                        4.3911             0.95575     1
# 43404                             136.850                        2.6672             2.79270     1
#
#        Interest_to_Sales  Cash_to_assets  Total_liabilities_to_Cash  cash_to_interest  \
# 43400           0.016424        0.004419                 159.815936          0.160455
# 43401           0.000000        0.006928                 139.580764               NaN
# 43402           0.000000       -0.029041                 -43.225550               NaN
# 43403           0.000000       -0.051326                 -14.494462               NaN
# 43404           0.000000       -0.007153                 -74.974472               NaN
#
#        Interest_to_cash  Financial_Expense_To_Total_Asset  Financial_expense_to_operating  \
# 43400          6.232272                          0.027602                        1.974248
# 43401               NaN                               NaN                             NaN
# 43402               NaN                               NaN                             NaN
# 43403               NaN                               NaN                             NaN
# 43404               NaN                               NaN                             NaN
#
#        Debt_Coverage_Ratio  Operating_income_Margin  Cash_conversion_cycle  \
# 43400             0.506522                 0.008338               56.43186
# 43401                  NaN                -0.131638               11.04368
# 43402                  NaN                -0.079390              147.46687
# 43403                  NaN                -0.130672               82.08653
# 43404                  NaN                -0.075920              121.87568
#
#        Cash_to_Financial_Expense  Financial_Leverage working_capital_indicator  Return_On_equity
# 43400                   0.160094            3.403792                         1          0.043902
# 43401                        NaN           -2.563840                         0          1.508504
# 43402                        NaN           -3.061943                         0          0.561776
# 43403                        NaN           10.726851                         1         -1.262473
# 43404                        NaN            2.156706                         0         -0.230699

# %%
filename='alldata.csv'
polish_Dataset.to_csv(filename,index=False)

# %%
files.download('alldata.csv')

# %% [markdown]
# # Initial Description Analysis

# %%
category_counts = polish_Dataset['class'].value_counts()
ax = category_counts.plot(kind='bar')
category_counts.plot(kind='bar')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.legend(['0: Healthy', '1: Bankrupt'])
plt.show()

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline

    import matplotlib.pyplot as plt

    # Generating multiple subplots
    fig, subPlot = plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20, 5))
    fig.suptitle('Bar charts of: ' + str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar', ax=subPlot[plotNumber])

# %%
import matplotlib.pyplot as plt

continuous_cols = ['net_profit/total assets','Total_Liabilities/total_assets','Working_Capital_to_Total_Assets_Ratio','Current_Ratio','Defensive_Interval_Ratio']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['gross_profit+extraordinary_items+financial_expenses)/total','gross_profit/short-term_liabilities','total_assets/total_liabilities']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['Retained_Earnings_to_Total_Assets_Ratio','Operating_Income_to_Total_Asset_ratio','book_value_of_equity/total_liabilities','Asset_Turnover_Ratio','Equity_to_Total_Assets_Ratio']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['gross_profit/total_assets','gross_profit/sales','(inventory∗365)/sales','sales(n)/sales(n-1)']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['profit_on_operating_activities/total_assets','net_profit/sales','gross_profit(in3years)/total_assets','(equity-share_capital)/total_assets']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['(net_profit+depreciation)/total_liabilities','profit_on_operating_activities/financial_expenses','working_capital/fixed_assets','logarithm_of_total_assets','(total_liabilities-cash)/sales']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['(gross_profit+interest)/sales','(current_liabilities∗365)/cost_of_products_sold','operating_expenses/short-term_liabilities','operating_expenses_/_total_liabilities']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['profit_on_sales/total_assets','total_sales/total_assets','(current_assets-inventories)/long-term_liabilities','constant_capital/total_assets']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['profit_on_sales/sales','(current_assets-inventory-receivables)/short-term liabilities']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))','profit_on_operating_activities/sales','rotation_receivables+inventory_turnover_in_days']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['(receivables∗365)/sales','net_profit/inventory','(current_assets-inventory)/short-term_liabilities','(inventory∗365)/cost_of_products_sold']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['EBITDA_(profit_on_operating_activities-depreciation)/total_assets','EBITDA_(profit_on_operating_activities-depreciation)/sales','current_assets/total_liabilities']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['short-term_liabilities/total_assets','(short-term_liabilities∗365)/cost_of_products_sold)','equity/fixed_assets','constant_capital/fixed_assets']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['working_capital','(sales-cost_of_products_sold)/sales','(current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)']

fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['total_costs/total_sales','long-term_liabilities/equity','sales/inventory','sales/receivables','(short-term_liabilities∗365)/sales']
fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
continuous_cols = ['sales/short-term liabilities','sales/fixed assets']
fig, axes = plt.subplots(nrows=1, ncols=len(continuous_cols), figsize=(18, 5))

# Creating box plots for each continuous predictor against the Target Variable "class"
for col, ax in zip(continuous_cols, axes):
    polish_Dataset.boxplot(column=col, by='class', figsize=(5,5), vert=True, ax=ax)
    ax.set_title(col)
plt.show()

# %%
polish_Dataset.isnull().any()
# Out:
# year                                                                                   False
# net_profit/total assets                                                                 True
# Total_Liabilities/total_assets                                                          True
# Working_Capital_to_Total_Assets_Ratio                                                   True
# Current_Ratio                                                                           True
# Defensive_Interval_Ratio                                                                True
# Retained_Earnings_to_Total_Assets_Ratio                                                 True
# Operating_Income_to_Total_Asset_ratio                                                   True
# book_value_of_equity/total_liabilities                                                  True
# Asset_Turnover_Ratio                                                                    True
# Equity_to_Total_Assets_Ratio                                                            True
# gross_profit+extraordinary_items+financial_expenses)/total                              True
# gross_profit/short-term_liabilities                                                     True
# (gross_profit+depreciation)/sales                                                       True
# (gross_profit+interest)/total_assets                                                    True
# (total_liabilities∗365)/(gross_profit+depreciation)                                     True
# (gross profit+depreciation)/total_liabilities                                           True
# total_assets/total_liabilities                                                          True
# gross_profit/total_assets                                                               True
# gross_profit/sales                                                                      True
# (inventory∗365)/sales                                                                   True
# sales(n)/sales(n-1)                                                                     True
# profit_on_operating_activities/total_assets                                             True
# net_profit/sales                                                                        True
# gross_profit(in3years)/total_assets                                                     True
# (equity-share_capital)/total_assets                                                     True
# (net_profit+depreciation)/total_liabilities                                             True
# profit_on_operating_activities/financial_expenses                                       True
# working_capital/fixed_assets                                                            True
# logarithm_of_total_assets                                                               True
# (total_liabilities-cash)/sales                                                          True
# (gross_profit+interest)/sales                                                           True
# (current_liabilities∗365)/cost_of_products_sold                                         True
# operating_expenses/short-term_liabilities                                               True
# operating_expenses_/_total_liabilities                                                  True
# profit_on_sales/total_assets                                                            True
# total_sales/total_assets                                                                True
# (current_assets-inventories)/long-term_liabilities                                      True
# constant_capital/total_assets                                                           True
# profit_on_sales/sales                                                                   True
# (current_assets-inventory-receivables)/short-term liabilities                           True
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))              True
# profit_on_operating_activities/sales                                                    True
# rotation_receivables+inventory_turnover_in_days                                         True
# (receivables∗365)/sales                                                                 True
# net_profit/inventory                                                                    True
# (current_assets-inventory)/short-term_liabilities                                       True
# (inventory∗365)/cost_of_products_sold                                                   True
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                       True
# EBITDA_(profit_on_operating_activities-depreciation)/sales                              True
# current_assets/total_liabilities                                                        True
# short-term_liabilities/total_assets                                                     True
# (short-term_liabilities∗365)/cost_of_products_sold)                                     True
# equity/fixed_assets                                                                     True
# constant_capital/fixed_assets                                                           True
# working_capital                                                                         True
# (sales-cost_of_products_sold)/sales                                                     True
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)     True
# total_costs/total_sales                                                                 True
# long-term_liabilities/equity                                                            True
# sales/inventory                                                                         True
# sales/receivables                                                                       True
# (short-term_liabilities∗365)/sales                                                      True
# sales/short-term liabilities                                                            True
# sales/fixed assets                                                                      True
# class                                                                                  False
# Interest_to_Sales                                                                       True
# Cash_to_assets                                                                          True
# Total_liabilities_to_Cash                                                               True
# cash_to_interest                                                                        True
# Interest_to_cash                                                                        True
# Financial_Expense_To_Total_Asset                                                        True
# Financial_expense_to_operating                                                          True
# Debt_Coverage_Ratio                                                                     True
# Operating_income_Margin                                                                 True
# Cash_conversion_cycle                                                                   True
# Cash_to_Financial_Expense                                                               True
# Financial_Leverage                                                                      True
# working_capital_indicator                                                              False
# Return_On_equity                                                                        True
# dtype: bool

# %%
#number of null
Features_Null=(polish_Dataset.isnull().sum())
Features_Null
# Out:
# year                                                                                       0
# net_profit/total assets                                                                    8
# Total_Liabilities/total_assets                                                             8
# Working_Capital_to_Total_Assets_Ratio                                                      8
# Current_Ratio                                                                            134
# Defensive_Interval_Ratio                                                                  89
# Retained_Earnings_to_Total_Assets_Ratio                                                    8
# Operating_Income_to_Total_Asset_ratio                                                      8
# book_value_of_equity/total_liabilities                                                    94
# Asset_Turnover_Ratio                                                                       9
# Equity_to_Total_Assets_Ratio                                                               8
# gross_profit+extraordinary_items+financial_expenses)/total                                44
# gross_profit/short-term_liabilities                                                      134
# (gross_profit+depreciation)/sales                                                        127
# (gross_profit+interest)/total_assets                                                       8
# (total_liabilities∗365)/(gross_profit+depreciation)                                       36
# (gross profit+depreciation)/total_liabilities                                             95
# total_assets/total_liabilities                                                            94
# gross_profit/total_assets                                                                  8
# gross_profit/sales                                                                       128
# (inventory∗365)/sales                                                                    127
# sales(n)/sales(n-1)                                                                     5854
# profit_on_operating_activities/total_assets                                                8
# net_profit/sales                                                                         127
# gross_profit(in3years)/total_assets                                                      922
# (equity-share_capital)/total_assets                                                        8
# (net_profit+depreciation)/total_liabilities                                               95
# profit_on_operating_activities/financial_expenses                                       2764
# working_capital/fixed_assets                                                             812
# logarithm_of_total_assets                                                                  8
# (total_liabilities-cash)/sales                                                           127
# (gross_profit+interest)/sales                                                            127
# (current_liabilities∗365)/cost_of_products_sold                                          368
# operating_expenses/short-term_liabilities                                                134
# operating_expenses_/_total_liabilities                                                    94
# profit_on_sales/total_assets                                                               8
# total_sales/total_assets                                                                   8
# (current_assets-inventories)/long-term_liabilities                                     18984
# constant_capital/total_assets                                                              8
# profit_on_sales/sales                                                                    127
# (current_assets-inventory-receivables)/short-term liabilities                            134
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))               754
# profit_on_operating_activities/sales                                                     127
# rotation_receivables+inventory_turnover_in_days                                          127
# (receivables∗365)/sales                                                                  127
# net_profit/inventory                                                                    2147
# (current_assets-inventory)/short-term_liabilities                                        135
# (inventory∗365)/cost_of_products_sold                                                    297
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                          9
# EBITDA_(profit_on_operating_activities-depreciation)/sales                               127
# current_assets/total_liabilities                                                          94
# short-term_liabilities/total_assets                                                        8
# (short-term_liabilities∗365)/cost_of_products_sold)                                      301
# equity/fixed_assets                                                                      812
# constant_capital/fixed_assets                                                            812
# working_capital                                                                            1
# (sales-cost_of_products_sold)/sales                                                      127
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)        7
# total_costs/total_sales                                                                   84
# long-term_liabilities/equity                                                               7
# sales/inventory                                                                         2152
# sales/receivables                                                                        102
# (short-term_liabilities∗365)/sales                                                       127
# sales/short-term liabilities                                                             134
# sales/fixed assets                                                                       812
# class                                                                                      0
# Interest_to_Sales                                                                        128
# Cash_to_assets                                                                           135
# Total_liabilities_to_Cash                                                                167
# cash_to_interest                                                                       19876
# Interest_to_cash                                                                       19894
# Financial_Expense_To_Total_Asset                                                        5741
# Financial_expense_to_operating                                                          5770
# Debt_Coverage_Ratio                                                                     5753
# Operating_income_Margin                                                                   84
# Cash_conversion_cycle                                                                    419
# Cash_to_Financial_Expense                                                               5838
# Financial_Leverage                                                                        12
# working_capital_indicator                                                                  0
# Return_On_equity                                                                         139
# dtype: int64

# %%
polish_Dataset.corr()
# Out:
#                                                                                          year  \
# year                                                                                 1.000000
# net_profit/total assets                                                             -0.004052
# Total_Liabilities/total_assets                                                      -0.004834
# Working_Capital_to_Total_Assets_Ratio                                                0.004653
# Current_Ratio                                                                        0.004548
# Defensive_Interval_Ratio                                                             0.001471
# Retained_Earnings_to_Total_Assets_Ratio                                             -0.000409
# Operating_Income_to_Total_Asset_ratio                                               -0.019313
# book_value_of_equity/total_liabilities                                               0.005614
# Asset_Turnover_Ratio                                                                -0.017984
# Equity_to_Total_Assets_Ratio                                                        -0.021114
# gross_profit+extraordinary_items+financial_expenses)/total                          -0.019025
# gross_profit/short-term_liabilities                                                 -0.000910
# (gross_profit+depreciation)/sales                                                   -0.006130
# (gross_profit+interest)/total_assets                                                -0.019312
# (total_liabilities∗365)/(gross_profit+depreciation)                                  0.002806
# (gross profit+depreciation)/total_liabilities                                       -0.000490
# total_assets/total_liabilities                                                       0.005595
# gross_profit/total_assets                                                           -0.018880
# gross_profit/sales                                                                  -0.004937
# (inventory∗365)/sales                                                               -0.007237
# sales(n)/sales(n-1)                                                                 -0.009455
# profit_on_operating_activities/total_assets                                         -0.016220
# net_profit/sales                                                                    -0.005043
# gross_profit(in3years)/total_assets                                                 -0.011841
# (equity-share_capital)/total_assets                                                 -0.016473
# (net_profit+depreciation)/total_liabilities                                         -0.000569
# profit_on_operating_activities/financial_expenses                                   -0.006109
# working_capital/fixed_assets                                                         0.013252
# logarithm_of_total_assets                                                           -0.015942
# (total_liabilities-cash)/sales                                                      -0.007532
# (gross_profit+interest)/sales                                                       -0.004699
# (current_liabilities∗365)/cost_of_products_sold                                      0.001381
# operating_expenses/short-term_liabilities                                           -0.000124
# operating_expenses_/_total_liabilities                                              -0.000522
# profit_on_sales/total_assets                                                        -0.018639
# total_sales/total_assets                                                            -0.017789
# (current_assets-inventories)/long-term_liabilities                                  -0.006016
# constant_capital/total_assets                                                       -0.020650
# profit_on_sales/sales                                                               -0.005304
# (current_assets-inventory-receivables)/short-term liabilities                        0.009845
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))           0.000513
# profit_on_operating_activities/sales                                                -0.005691
# rotation_receivables+inventory_turnover_in_days                                     -0.006935
# (receivables∗365)/sales                                                             -0.006808
# net_profit/inventory                                                                 0.008052
# (current_assets-inventory)/short-term_liabilities                                    0.004457
# (inventory∗365)/cost_of_products_sold                                               -0.002627
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                   -0.013376
# EBITDA_(profit_on_operating_activities-depreciation)/sales                           0.006215
# current_assets/total_liabilities                                                     0.003010
# short-term_liabilities/total_assets                                                 -0.003462
# (short-term_liabilities∗365)/cost_of_products_sold)                                  0.001655
# equity/fixed_assets                                                                 -0.019033
# constant_capital/fixed_assets                                                       -0.018786
# working_capital                                                                      0.009445
# (sales-cost_of_products_sold)/sales                                                  0.007262
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation) -0.006660
# total_costs/total_sales                                                             -0.007609
# long-term_liabilities/equity                                                        -0.002881
# sales/inventory                                                                      0.001804
# sales/receivables                                                                    0.000938
# (short-term_liabilities∗365)/sales                                                  -0.006390
# sales/short-term liabilities                                                        -0.001623
# sales/fixed assets                                                                  -0.016681
# class                                                                                0.043488
# Interest_to_Sales                                                                    0.005840
# Cash_to_assets                                                                       0.001698
# Total_liabilities_to_Cash                                                           -0.007498
# cash_to_interest                                                                     0.012476
# Interest_to_cash                                                                    -0.002826
# Financial_Expense_To_Total_Asset                                                     0.002699
# Financial_expense_to_operating                                                      -0.009278
# Debt_Coverage_Ratio                                                                 -0.006008
# Operating_income_Margin                                                             -0.006338
# Cash_conversion_cycle                                                               -0.007289
# Cash_to_Financial_Expense                                                            0.002693
# Financial_Leverage                                                                  -0.001960
# working_capital_indicator                                                            0.013728
# Return_On_equity                                                                    -0.004974
#
#                                                                                      net_profit/total assets  \
# year                                                                                               -0.004052
# net_profit/total assets                                                                             1.000000
# Total_Liabilities/total_assets                                                                     -0.104146
# Working_Capital_to_Total_Assets_Ratio                                                               0.058037
# Current_Ratio                                                                                       0.000855
# Defensive_Interval_Ratio                                                                            0.002744
# Retained_Earnings_to_Total_Assets_Ratio                                                             0.315139
# Operating_Income_to_Total_Asset_ratio                                                               0.408428
# book_value_of_equity/total_liabilities                                                              0.000184
# Asset_Turnover_Ratio                                                                               -0.225720
# Equity_to_Total_Assets_Ratio                                                                       -0.240254
# gross_profit+extraordinary_items+financial_expenses)/total                                          0.492120
# gross_profit/short-term_liabilities                                                                 0.168760
# (gross_profit+depreciation)/sales                                                                   0.001861
# (gross_profit+interest)/total_assets                                                                0.408428
# (total_liabilities∗365)/(gross_profit+depreciation)                                                 0.000241
# (gross profit+depreciation)/total_liabilities                                                       0.163944
# total_assets/total_liabilities                                                                      0.000366
# gross_profit/total_assets                                                                           0.406668
# gross_profit/sales                                                                                  0.003488
# (inventory∗365)/sales                                                                              -0.000050
# sales(n)/sales(n-1)                                                                                -0.001488
# profit_on_operating_activities/total_assets                                                         0.501354
# net_profit/sales                                                                                    0.003614
# gross_profit(in3years)/total_assets                                                                 0.334890
# (equity-share_capital)/total_assets                                                                -0.413919
# (net_profit+depreciation)/total_liabilities                                                         0.169085
# profit_on_operating_activities/financial_expenses                                                   0.007637
# working_capital/fixed_assets                                                                        0.002828
# logarithm_of_total_assets                                                                           0.039503
# (total_liabilities-cash)/sales                                                                      0.000080
# (gross_profit+interest)/sales                                                                       0.003483
# (current_liabilities∗365)/cost_of_products_sold                                                    -0.002572
# operating_expenses/short-term_liabilities                                                           0.005253
# operating_expenses_/_total_liabilities                                                              0.083414
# profit_on_sales/total_assets                                                                        0.313929
# total_sales/total_assets                                                                           -0.279624
# (current_assets-inventories)/long-term_liabilities                                                  0.001579
# constant_capital/total_assets                                                                      -0.233328
# profit_on_sales/sales                                                                               0.000915
# (current_assets-inventory-receivables)/short-term liabilities                                       0.002952
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))                          0.000174
# profit_on_operating_activities/sales                                                                0.002901
# rotation_receivables+inventory_turnover_in_days                                                    -0.000086
# (receivables∗365)/sales                                                                            -0.000098
# net_profit/inventory                                                                                0.000966
# (current_assets-inventory)/short-term_liabilities                                                   0.000662
# (inventory∗365)/cost_of_products_sold                                                              -0.000836
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                                   0.583213
# EBITDA_(profit_on_operating_activities-depreciation)/sales                                          0.001109
# current_assets/total_liabilities                                                                    0.000918
# short-term_liabilities/total_assets                                                                -0.056489
# (short-term_liabilities∗365)/cost_of_products_sold)                                                -0.001436
# equity/fixed_assets                                                                                -0.031724
# constant_capital/fixed_assets                                                                      -0.031581
# working_capital                                                                                     0.004015
# (sales-cost_of_products_sold)/sales                                                                 0.000044
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)                 0.007764
# total_costs/total_sales                                                                            -0.000302
# long-term_liabilities/equity                                                                       -0.000220
# sales/inventory                                                                                     0.000213
# sales/receivables                                                                                   0.000582
# (short-term_liabilities∗365)/sales                                                                  0.000321
# sales/short-term liabilities                                                                        0.008387
# sales/fixed assets                                                                                 -0.069021
# class                                                                                              -0.026649
# Interest_to_Sales                                                                                  -0.000022
# Cash_to_assets                                                                                     -0.034360
# Total_liabilities_to_Cash                                                                          -0.002174
# cash_to_interest                                                                                    0.001487
# Interest_to_cash                                                                                    0.002515
# Financial_Expense_To_Total_Asset                                                                    0.171492
# Financial_expense_to_operating                                                                      0.000109
# Debt_Coverage_Ratio                                                                                 0.006501
# Operating_income_Margin                                                                             0.003091
# Cash_conversion_cycle                                                                              -0.000326
# Cash_to_Financial_Expense                                                                          -0.004463
# Financial_Leverage                                                                                 -0.000365
# working_capital_indicator                                                                           0.033684
# Return_On_equity                                                                                    0.004326
#
#                                                                                      Total_Liabilities/total_assets  \
# year                                                                                                      -0.004834
# net_profit/total assets                                                                                   -0.104146
# Total_Liabilities/total_assets                                                                             1.000000
# Working_Capital_to_Total_Assets_Ratio                                                                     -0.926983
# Current_Ratio                                                                                             -0.001589
# Defensive_Interval_Ratio                                                                                  -0.036322
# Retained_Earnings_to_Total_Assets_Ratio                                                                   -0.842916
# Operating_Income_to_Total_Asset_ratio                                                                      0.102020
# book_value_of_equity/total_liabilities                                                                    -0.002385
# Asset_Turnover_Ratio                                                                                      -0.016594
# Equity_to_Total_Assets_Ratio                                                                              -0.409341
# gross_profit+extraordinary_items+financial_expenses)/total                                                -0.008287
# gross_profit/short-term_liabilities                                                                       -0.001331
# (gross_profit+depreciation)/sales                                                                          0.001069
# (gross_profit+interest)/total_assets                                                                       0.102020
# (total_liabilities∗365)/(gross_profit+depreciation)                                                        0.001067
# (gross profit+depreciation)/total_liabilities                                                             -0.001688
# total_assets/total_liabilities                                                                            -0.002414
# gross_profit/total_assets                                                                                  0.101585
# gross_profit/sales                                                                                         0.001636
# (inventory∗365)/sales                                                                                      0.000186
# sales(n)/sales(n-1)                                                                                       -0.000014
# profit_on_operating_activities/total_assets                                                               -0.022009
# net_profit/sales                                                                                           0.001357
# gross_profit(in3years)/total_assets                                                                       -0.101397
# (equity-share_capital)/total_assets                                                                       -0.432800
# (net_profit+depreciation)/total_liabilities                                                               -0.001595
# profit_on_operating_activities/financial_expenses                                                         -0.002499
# working_capital/fixed_assets                                                                              -0.007938
# logarithm_of_total_assets                                                                                 -0.053410
# (total_liabilities-cash)/sales                                                                             0.022282
# (gross_profit+interest)/sales                                                                              0.001813
# (current_liabilities∗365)/cost_of_products_sold                                                            0.035563
# operating_expenses/short-term_liabilities                                                                 -0.002813
# operating_expenses_/_total_liabilities                                                                    -0.002209
# profit_on_sales/total_assets                                                                              -0.028969
# total_sales/total_assets                                                                                  -0.014516
# (current_assets-inventories)/long-term_liabilities                                                        -0.002773
# constant_capital/total_assets                                                                             -0.421186
# profit_on_sales/sales                                                                                     -0.001926
# (current_assets-inventory-receivables)/short-term liabilities                                             -0.002796
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))                                -0.000429
# profit_on_operating_activities/sales                                                                      -0.000546
# rotation_receivables+inventory_turnover_in_days                                                            0.000528
# (receivables∗365)/sales                                                                                    0.000644
# net_profit/inventory                                                                                      -0.002254
# (current_assets-inventory)/short-term_liabilities                                                         -0.001408
# (inventory∗365)/cost_of_products_sold                                                                      0.000935
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                                         -0.019100
# EBITDA_(profit_on_operating_activities-depreciation)/sales                                                -0.000460
# current_assets/total_liabilities                                                                          -0.001589
# short-term_liabilities/total_assets                                                                        0.926773
# (short-term_liabilities∗365)/cost_of_products_sold)                                                        0.010729
# equity/fixed_assets                                                                                       -0.012609
# constant_capital/fixed_assets                                                                             -0.012329
# working_capital                                                                                           -0.009580
# (sales-cost_of_products_sold)/sales                                                                       -0.000235
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)                       -0.000793
# total_costs/total_sales                                                                                    0.000270
# long-term_liabilities/equity                                                                               0.000617
# sales/inventory                                                                                           -0.000078
# sales/receivables                                                                                         -0.001191
# (short-term_liabilities∗365)/sales                                                                         0.046769
# sales/short-term liabilities                                                                              -0.003339
# sales/fixed assets                                                                                        -0.015647
# class                                                                                                      0.035236
# Interest_to_Sales                                                                                          0.004478
# Cash_to_assets                                                                                            -0.474856
# Total_liabilities_to_Cash                                                                                  0.000727
# cash_to_interest                                                                                          -0.029228
# Interest_to_cash                                                                                          -0.000115
# Financial_Expense_To_Total_Asset                                                                          -0.300689
# Financial_expense_to_operating                                                                            -0.000388
# Debt_Coverage_Ratio                                                                                       -0.002081
# Operating_income_Margin                                                                                   -0.001459
# Cash_conversion_cycle                                                                                      0.000830
# Cash_to_Financial_Expense                                                                                 -0.151619
# Financial_Leverage                                                                                         0.000962
# working_capital_indicator                                                                                 -0.053118
# Return_On_equity                                                                                          -0.001631
#
#                                                                                      Working_Capital_to_Total_Assets_Ratio  \
# year                                                                                                              0.004653
# net_profit/total assets                                                                                           0.058037
# Total_Liabilities/total_assets                                                                                   -0.926983
# Working_Capital_to_Total_Assets_Ratio                                                                             1.000000
# Current_Ratio                                                                                                     0.002335
# Defensive_Interval_Ratio                                                                                          0.038877
# Retained_Earnings_to_Total_Assets_Ratio                                                                           0.760215
# Operating_Income_to_Total_Asset_ratio                                                                             0.033521
# book_value_of_equity/total_liabilities                                                                            0.001267
# Asset_Turnover_Ratio                                                                                             -0.002981
# Equity_to_Total_Assets_Ratio                                                                                      0.369558
# gross_profit+extraordinary_items+financial_expenses)/total                                                       -0.011209
# gross_profit/short-term_liabilities                                                                               0.001271
# (gross_profit+depreciation)/sales                                                                                -0.001188
# (gross_profit+interest)/total_assets                                                                              0.033521
# (total_liabilities∗365)/(gross_profit+depreciation)                                                              -0.001064
# (gross profit+depreciation)/total_liabilities                                                                     0.001483
# total_assets/total_liabilities                                                                                    0.001267
# gross_profit/total_assets                                                                                         0.033362
# gross_profit/sales                                                                                               -0.002000
# (inventory∗365)/sales                                                                                             0.000017
# sales(n)/sales(n-1)                                                                                               0.000110
# profit_on_operating_activities/total_assets                                                                       0.003924
# net_profit/sales                                                                                                 -0.002050
# gross_profit(in3years)/total_assets                                                                               0.086869
# (equity-share_capital)/total_assets                                                                               0.440442
# (net_profit+depreciation)/total_liabilities                                                                       0.001405
# profit_on_operating_activities/financial_expenses                                                                 0.002615
# working_capital/fixed_assets                                                                                      0.052868
# logarithm_of_total_assets                                                                                         0.046723
# (total_liabilities-cash)/sales                                                                                   -0.023566
# (gross_profit+interest)/sales                                                                                    -0.002183
# (current_liabilities∗365)/cost_of_products_sold                                                                  -0.038301
# operating_expenses/short-term_liabilities                                                                         0.003885
# operating_expenses_/_total_liabilities                                                                            0.002700
# profit_on_sales/total_assets                                                                                      0.008467
# total_sales/total_assets                                                                                         -0.004628
# (current_assets-inventories)/long-term_liabilities                                                                0.016808
# constant_capital/total_assets                                                                                     0.367322
# profit_on_sales/sales                                                                                             0.002039
# (current_assets-inventory-receivables)/short-term liabilities                                                     0.004295
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))                                        0.000510
# profit_on_operating_activities/sales                                                                              0.000945
# rotation_receivables+inventory_turnover_in_days                                                                  -0.000301
# (receivables∗365)/sales                                                                                          -0.000408
# net_profit/inventory                                                                                              0.002869
# (current_assets-inventory)/short-term_liabilities                                                                 0.002145
# (inventory∗365)/cost_of_products_sold                                                                            -0.001054
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                                                 0.004295
# EBITDA_(profit_on_operating_activities-depreciation)/sales                                                        0.000343
# current_assets/total_liabilities                                                                                  0.002256
# short-term_liabilities/total_assets                                                                              -0.998219
# (short-term_liabilities∗365)/cost_of_products_sold)                                                              -0.012019
# equity/fixed_assets                                                                                               0.001822
# constant_capital/fixed_assets                                                                                     0.002118
# working_capital                                                                                                   0.011102
# (sales-cost_of_products_sold)/sales                                                                               0.000017
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)                               0.000779
# total_costs/total_sales                                                                                          -0.000034
# long-term_liabilities/equity                                                                                     -0.000247
# sales/inventory                                                                                                   0.000377
# sales/receivables                                                                                                -0.000139
# (short-term_liabilities∗365)/sales                                                                               -0.050052
# sales/short-term liabilities                                                                                      0.004044
# sales/fixed assets                                                                                               -0.000910
# class                                                                                                            -0.035128
# Interest_to_Sales                                                                                                -0.004656
# Cash_to_assets                                                                                                    0.510258
# Total_liabilities_to_Cash                                                                                        -0.000156
# cash_to_interest                                                                                                  0.030457
# Interest_to_cash                                                                                                  0.000376
# Financial_Expense_To_Total_Asset                                                                                 -0.123087
# Financial_expense_to_operating                                                                                    0.000056
# Debt_Coverage_Ratio                                                                                               0.002282
# Operating_income_Margin                                                                                           0.001306
# Cash_conversion_cycle                                                                                            -0.000627
# Cash_to_Financial_Expense                                                                                         0.167618
# Financial_Leverage                                                                                               -0.000304
# working_capital_indicator                                                                                         0.071761
# Return_On_equity                                                                                                  0.001757
#
#                                                                                      Current_Ratio  \
# year                                                                                      0.004548
# net_profit/total assets                                                                   0.000855
# Total_Liabilities/total_assets                                                           -0.001589
# Working_Capital_to_Total_Assets_Ratio                                                     0.002335
# Current_Ratio                                                                             1.000000
# Defensive_Interval_Ratio                                                                  0.001852
# Retained_Earnings_to_Total_Assets_Ratio                                                   0.000050
# Operating_Income_to_Total_Asset_ratio                                                     0.000167
# book_value_of_equity/total_liabilities                                                    0.598635
# Asset_Turnover_Ratio                                                                     -0.000392
# Equity_to_Total_Assets_Ratio                                                              0.001668
# gross_profit+extraordinary_items+financial_expenses)/total                                0.000094
# gross_profit/short-term_liabilities                                                       0.147836
# (gross_profit+depreciation)/sales                                                         0.008599
# (gross_profit+interest)/total_assets                                                      0.000167
# (total_liabilities∗365)/(gross_profit+depreciation)                                      -0.000299
# (gross profit+depreciation)/total_liabilities                                             0.150422
# total_assets/total_liabilities                                                            0.596905
# gross_profit/total_assets                                                                 0.000143
# gross_profit/sales                                                                        0.016136
# (inventory∗365)/sales                                                                    -0.000278
# sales(n)/sales(n-1)                                                                      -0.000153
# profit_on_operating_activities/total_assets                                              -0.000107
# net_profit/sales                                                                          0.013794
# gross_profit(in3years)/total_assets                                                      -0.000070
# (equity-share_capital)/total_assets                                                       0.001363
# (net_profit+depreciation)/total_liabilities                                               0.130000
# profit_on_operating_activities/financial_expenses                                         0.000100
# working_capital/fixed_assets                                                              0.014430
# logarithm_of_total_assets                                                                -0.019347
# (total_liabilities-cash)/sales                                                           -0.001431
# (gross_profit+interest)/sales                                                             0.016205
# (current_liabilities∗365)/cost_of_products_sold                                          -0.000203
# operating_expenses/short-term_liabilities                                                 0.118596
# operating_expenses_/_total_liabilities                                                   -0.033643
# profit_on_sales/total_assets                                                             -0.000202
# total_sales/total_assets                                                                 -0.000565
# (current_assets-inventories)/long-term_liabilities                                        0.005000
# constant_capital/total_assets                                                             0.001451
# profit_on_sales/sales                                                                    -0.001472
# (current_assets-inventory-receivables)/short-term liabilities                             0.493623
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))               -0.000090
# profit_on_operating_activities/sales                                                     -0.006260
# rotation_receivables+inventory_turnover_in_days                                          -0.000036
# (receivables∗365)/sales                                                                   0.000047
# net_profit/inventory                                                                      0.011911
# (current_assets-inventory)/short-term_liabilities                                         0.999920
# (inventory∗365)/cost_of_products_sold                                                    -0.000176
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                         0.000138
# EBITDA_(profit_on_operating_activities-depreciation)/sales                               -0.001933
# current_assets/total_liabilities                                                          0.997592
# short-term_liabilities/total_assets                                                      -0.001533
# (short-term_liabilities∗365)/cost_of_products_sold)                                      -0.000197
# equity/fixed_assets                                                                       0.004699
# constant_capital/fixed_assets                                                             0.005098
# working_capital                                                                          -0.000077
# (sales-cost_of_products_sold)/sales                                                       0.000281
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)       0.000125
# total_costs/total_sales                                                                  -0.000289
# long-term_liabilities/equity                                                             -0.000266
# sales/inventory                                                                           0.001670
# sales/receivables                                                                         0.004387
# (short-term_liabilities∗365)/sales                                                       -0.000704
# sales/short-term liabilities                                                              0.039447
# sales/fixed assets                                                                        0.000122
# class                                                                                    -0.001652
# Interest_to_Sales                                                                         0.002734
# Cash_to_assets                                                                            0.000642
# Total_liabilities_to_Cash                                                                -0.000041
# cash_to_interest                                                                          0.013698
# Interest_to_cash                                                                         -0.001082
# Financial_Expense_To_Total_Asset                                                         -0.000446
# Financial_expense_to_operating                                                           -0.000050
# Debt_Coverage_Ratio                                                                       0.001165
# Operating_income_Margin                                                                   0.002511
# Cash_conversion_cycle                                                                    -0.000116
# Cash_to_Financial_Expense                                                                 0.005437
# Financial_Leverage                                                                       -0.000460
# working_capital_indicator                                                                 0.010043
# Return_On_equity                                                                          0.000144
#
#                                                                                      Defensive_Interval_Ratio  \
# year                                                                                                 0.001471
# net_profit/total assets                                                                              0.002744
# Total_Liabilities/total_assets                                                                      -0.036322
# Working_Capital_to_Total_Assets_Ratio                                                                0.038877
# Current_Ratio                                                                                        0.001852
# Defensive_Interval_Ratio                                                                             1.000000
# Retained_Earnings_to_Total_Assets_Ratio                                                              0.029288
# Operating_Income_to_Total_Asset_ratio                                                                0.001492
# book_value_of_equity/total_liabilities                                                               0.001631
# Asset_Turnover_Ratio                                                                                 0.000796
# Equity_to_Total_Assets_Ratio                                                                         0.014701
# gross_profit+extraordinary_items+financial_expenses)/total                                          -0.000624
# gross_profit/short-term_liabilities                                                                  0.000819
# (gross_profit+depreciation)/sales                                                                   -0.000507
# (gross_profit+interest)/total_assets                                                                 0.001492
# (total_liabilities∗365)/(gross_profit+depreciation)                                                 -0.039146
# (gross profit+depreciation)/total_liabilities                                                        0.000592
# total_assets/total_liabilities                                                                       0.001635
# gross_profit/total_assets                                                                            0.001490
# gross_profit/sales                                                                                  -0.000972
# (inventory∗365)/sales                                                                                0.000017
# sales(n)/sales(n-1)                                                                                  0.000050
# profit_on_operating_activities/total_assets                                                         -0.000062
# net_profit/sales                                                                                    -0.000782
# gross_profit(in3years)/total_assets                                                                  0.003286
# ...
# (gross_profit+interest)/total_assets                                                                  0.012069
# (total_liabilities∗365)/(gross_profit+depreciation)                                                  -0.002613
# (gross profit+depreciation)/total_liabilities                                                         0.010125
# total_assets/total_liabilities                                                                        0.012661
# gross_profit/total_assets                                                                             0.011962
# gross_profit/sales                                                                                    0.007357
# (inventory∗365)/sales                                                                                 0.002593
# sales(n)/sales(n-1)                                                                                  -0.009567
# profit_on_operating_activities/total_assets                                                           0.007138
# net_profit/sales                                                                                      0.007223
# gross_profit(in3years)/total_assets                                                                   0.012826
# (equity-share_capital)/total_assets                                                                   0.006062
# (net_profit+depreciation)/total_liabilities                                                           0.009352
# profit_on_operating_activities/financial_expenses                                                     0.017069
# working_capital/fixed_assets                                                                          0.030586
# logarithm_of_total_assets                                                                             0.006012
# (total_liabilities-cash)/sales                                                                       -0.005614
# (gross_profit+interest)/sales                                                                         0.007023
# (current_liabilities∗365)/cost_of_products_sold                                                      -0.008520
# operating_expenses/short-term_liabilities                                                             0.023633
# operating_expenses_/_total_liabilities                                                                0.016477
# profit_on_sales/total_assets                                                                          0.007188
# total_sales/total_assets                                                                             -0.017667
# (current_assets-inventories)/long-term_liabilities                                                    0.011646
# constant_capital/total_assets                                                                        -0.007337
# profit_on_sales/sales                                                                                 0.015029
# (current_assets-inventory-receivables)/short-term liabilities                                         0.019515
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))                            0.002625
# profit_on_operating_activities/sales                                                                  0.014871
# rotation_receivables+inventory_turnover_in_days                                                       0.001611
# (receivables∗365)/sales                                                                               0.001270
# net_profit/inventory                                                                                  0.010671
# (current_assets-inventory)/short-term_liabilities                                                     0.008924
# (inventory∗365)/cost_of_products_sold                                                                -0.009724
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                                     0.011467
# EBITDA_(profit_on_operating_activities-depreciation)/sales                                            0.002947
# current_assets/total_liabilities                                                                      0.009048
# short-term_liabilities/total_assets                                                                  -0.057316
# (short-term_liabilities∗365)/cost_of_products_sold)                                                  -0.015247
# equity/fixed_assets                                                                                  -0.021956
# constant_capital/fixed_assets                                                                        -0.021873
# working_capital                                                                                       0.131674
# (sales-cost_of_products_sold)/sales                                                                  -0.002464
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)                   0.016512
# total_costs/total_sales                                                                               0.002044
# long-term_liabilities/equity                                                                         -0.002966
# sales/inventory                                                                                       0.001437
# sales/receivables                                                                                    -0.004789
# (short-term_liabilities∗365)/sales                                                                   -0.008764
# sales/short-term liabilities                                                                          0.025144
# sales/fixed assets                                                                                   -0.021634
# class                                                                                                -0.115184
# Interest_to_Sales                                                                                    -0.008168
# Cash_to_assets                                                                                        0.013527
# Total_liabilities_to_Cash                                                                            -0.000377
# cash_to_interest                                                                                      0.045127
# Interest_to_cash                                                                                      0.001692
# Financial_Expense_To_Total_Asset                                                                     -0.016513
# Financial_expense_to_operating                                                                       -0.002922
# Debt_Coverage_Ratio                                                                                   0.016319
# Operating_income_Margin                                                                               0.004757
# Cash_conversion_cycle                                                                                -0.001518
# Cash_to_Financial_Expense                                                                             0.015463
# Financial_Leverage                                                                                   -0.010734
# working_capital_indicator                                                                             1.000000
# Return_On_equity                                                                                      0.013313
#
#                                                                                      Return_On_equity
# year                                                                                        -0.004974
# net_profit/total assets                                                                      0.004326
# Total_Liabilities/total_assets                                                              -0.001631
# Working_Capital_to_Total_Assets_Ratio                                                        0.001757
# Current_Ratio                                                                                0.000144
# Defensive_Interval_Ratio                                                                     0.000010
# Retained_Earnings_to_Total_Assets_Ratio                                                      0.001396
# Operating_Income_to_Total_Asset_ratio                                                        0.002429
# book_value_of_equity/total_liabilities                                                       0.000483
# Asset_Turnover_Ratio                                                                         0.000363
# Equity_to_Total_Assets_Ratio                                                                 0.000535
# gross_profit+extraordinary_items+financial_expenses)/total                                   0.002638
# gross_profit/short-term_liabilities                                                          0.000806
# (gross_profit+depreciation)/sales                                                            0.015141
# (gross_profit+interest)/total_assets                                                         0.002429
# (total_liabilities∗365)/(gross_profit+depreciation)                                          0.000025
# (gross profit+depreciation)/total_liabilities                                                0.001298
# total_assets/total_liabilities                                                               0.000487
# gross_profit/total_assets                                                                    0.002460
# gross_profit/sales                                                                           0.005148
# (inventory∗365)/sales                                                                        0.000416
# sales(n)/sales(n-1)                                                                          0.000866
# profit_on_operating_activities/total_assets                                                  0.002520
# net_profit/sales                                                                             0.005218
# gross_profit(in3years)/total_assets                                                          0.001856
# (equity-share_capital)/total_assets                                                          0.000932
# (net_profit+depreciation)/total_liabilities                                                  0.001419
# profit_on_operating_activities/financial_expenses                                            0.001608
# working_capital/fixed_assets                                                                 0.000979
# logarithm_of_total_assets                                                                    0.000059
# (total_liabilities-cash)/sales                                                               0.015641
# (gross_profit+interest)/sales                                                                0.006266
# (current_liabilities∗365)/cost_of_products_sold                                              0.000142
# operating_expenses/short-term_liabilities                                                    0.001087
# operating_expenses_/_total_liabilities                                                       0.000697
# profit_on_sales/total_assets                                                                 0.001611
# total_sales/total_assets                                                                     0.000395
# (current_assets-inventories)/long-term_liabilities                                           0.000061
# constant_capital/total_assets                                                                0.000366
# profit_on_sales/sales                                                                       -0.297309
# (current_assets-inventory-receivables)/short-term liabilities                                0.000419
# total_liabilities/((profit_on_operating_activities+depreciation)∗(12/365))                   0.000203
# profit_on_operating_activities/sales                                                         0.018160
# rotation_receivables+inventory_turnover_in_days                                              0.000489
# (receivables∗365)/sales                                                                      0.000512
# net_profit/inventory                                                                         0.007136
# (current_assets-inventory)/short-term_liabilities                                            0.000038
# (inventory∗365)/cost_of_products_sold                                                        0.000312
# EBITDA_(profit_on_operating_activities-depreciation)/total_assets                            0.002732
# EBITDA_(profit_on_operating_activities-depreciation)/sales                                  -0.016844
# current_assets/total_liabilities                                                             0.000598
# short-term_liabilities/total_assets                                                         -0.001533
# (short-term_liabilities∗365)/cost_of_products_sold)                                          0.000236
# equity/fixed_assets                                                                          0.000063
# constant_capital/fixed_assets                                                                0.000084
# working_capital                                                                              0.001483
# (sales-cost_of_products_sold)/sales                                                         -0.002214
# (current_assets-inventory-short-term_liabilities)/(sales–gross_profit-depreciation)          0.943178
# total_costs/total_sales                                                                      0.000016
# long-term_liabilities/equity                                                                -0.217482
# sales/inventory                                                                             -0.000630
# sales/receivables                                                                            0.000275
# (short-term_liabilities∗365)/sales                                                           0.000824
# sales/short-term liabilities                                                                 0.001028
# sales/fixed assets                                                                           0.000121
# class                                                                                       -0.010702
# Interest_to_Sales                                                                            0.028120
# Cash_to_assets                                                                              -0.032746
# Total_liabilities_to_Cash                                                                    0.000080
# cash_to_interest                                                                             0.000619
# Interest_to_cash                                                                             0.000293
# Financial_Expense_To_Total_Asset                                                             0.000267
# Financial_expense_to_operating                                                               0.000080
# Debt_Coverage_Ratio                                                                          0.001376
# Operating_income_Margin                                                                      0.000511
# Cash_conversion_cycle                                                                        0.000580
# Cash_to_Financial_Expense                                                                   -0.046073
# Financial_Leverage                                                                          -0.388024
# working_capital_indicator                                                                    0.013313
# Return_On_equity                                                                             1.000000

# %%
correlation_matrix = polish_Dataset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# based on initial observations, there are many extermine outliers in this dataset. The outliers are extreme in the 0 dataset.
#I will review each attribute and based on industry and financial experience will narrow the feature selections,
#before conducting any cleaning.

# %% [markdown]
# #Approach
#
# After careful analyzing all the variablea. The theme of selection came down to: **Reason for companies to go bankrupt:**
# 1.	**Failure of Business Strategy:**
#     a.	Lack of governance
#       i.	Failure to understand key metrics can lead to bankruptcy.
#     b.	Market trends
#       i.	Failing to see what competitors are doing
#       ii.	Market sentiment shifts and not adjusting
# 2.**	Inefficient use of assets**
#     a.	Management fails to generate income from assets
#     b.	Holding inventory too long
#     c.	Negative Working Capital
# 3.	**Too much Debt**
#     a.	Debt used to pay for Working capital
#     b.	Debt used to pay for equipment, plant
#     c.	Operating profits can’t cover interest
# 4.**	Not enough Cash flow**
#     a.	Not enough cash on hand
#     b.	Not collecting from account receivables
#     c.	Sales are not enough to cover expenses
#     d.	Cash conversation cycle is too long
#     e.	Cash can’t cover interest
#     f.	Days payable is too high

# %%
#analysis and data cleaning will be done on this new dataset. The exisiting dataset, will be used to compare results.
Bankrupt_model = polish_Dataset[['year','net_profit/total assets', 'net_profit/sales','Return_On_equity', 'sales(n)/sales(n-1)', 'Operating_Income_to_Total_Asset_ratio','(inventory∗365)/cost_of_products_sold', 'working_capital','Working_Capital_to_Total_Assets_Ratio', 'working_capital_indicator','Defensive_Interval_Ratio', 'Debt_Coverage_Ratio', 'Equity_to_Total_Assets_Ratio','Total_Liabilities/total_assets', 'Financial_Leverage', 'Financial_expense_to_operating','Interest_to_cash', 'Interest_to_Sales', 'Cash_to_Financial_Expense','Cash_to_assets', '(receivables∗365)/sales', 'total_costs/total_sales','Cash_conversion_cycle', '(short-term_liabilities∗365)/cost_of_products_sold)','class']]
Bankrupt_model.head()
# Out:
#    year  net_profit/total assets  net_profit/sales  Return_On_equity  sales(n)/sales(n-1)  \
# 0     1                 0.200550          0.119980          0.413683               1.2479
# 1     1                 0.209120          0.123040          0.420018               1.4293
# 2     1                 0.248660          0.189960          0.817738               1.4283
# 3     1                 0.081483          0.062782          0.148458               1.5069
# 4     1                 0.187320          0.115530          0.486231                  NaN
#
#    Operating_Income_to_Total_Asset_ratio  (inventory∗365)/cost_of_products_sold  working_capital  \
# 0                               0.249760                                 49.394         348690.0
# 1                               0.258340                                100.130           2304.6
# 2                               0.309060                                 96.372           6332.7
# 3                               0.092704                                 84.344          20545.0
# 4                               0.187320                                 65.936           3186.6
#
#    Working_Capital_to_Total_Assets_Ratio working_capital_indicator  Defensive_Interval_Ratio  \
# 0                                0.39641                         1                   32.3510
# 1                                0.47225                         1                   14.7860
# 2                                0.26713                         1                   -1.1523
# 3                                0.45879                         1                   51.9520
# 4                                0.22960                         1                   -7.3128
#
#    Debt_Coverage_Ratio  Equity_to_Total_Assets_Ratio  Total_Liabilities/total_assets  \
# 0             1.701710                       0.50494                         0.37951
# 1            92.109260                       0.49788                         0.49988
# 2            87.847190                       0.30408                         0.69592
# 3             0.755084                       0.57353                         0.30734
# 4             1.335382                       0.38677                         0.61323
#
#    Financial_Leverage  Financial_expense_to_operating  Interest_to_cash  Interest_to_Sales  \
# 0            1.980433                        0.587644               NaN            0.00000
# 1            2.008516                        0.010857               NaN            0.00000
# 2            3.288608                        0.011383          0.018246            0.00205
# 3            1.743588                        1.324356               NaN            0.00000
# 4            2.585516                        0.748849               NaN            0.00000
#
#    Cash_to_Financial_Expense  Cash_to_assets  (receivables∗365)/sales  total_costs/total_sales  \
# 0                   1.187442        0.174281                   71.050                  0.87804
# 1                  14.801829        0.041515                  111.510                  0.85300
# 2                  41.802992        0.147069                   92.381                  0.76599
# 3                   0.918933        0.112820                  100.980                  0.94598
# 4                   1.135875        0.159334                   84.574                  0.86515
#
#    Cash_conversion_cycle  (short-term_liabilities∗365)/cost_of_products_sold) class
# 0              120.18608                                              0.25792     0
# 1              211.30528                                              0.33472     0
# 2              188.26826                                              0.48474     0
# 3              185.07367                                              0.25033     0
# 4              150.10715                                              0.40285     0

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(Bankrupt_model.corr(), annot=False, cmap='coolwarm', fmt=".2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.options.display.float_format = "{:.3f}".format
Bankrupt_model.describe()
# Out:
#            year  net_profit/total assets  net_profit/sales  Return_On_equity  sales(n)/sales(n-1)  \
# count 43405.000                43397.000         43278.000         43266.000            37551.000
# mean      2.940                    0.035             0.139             0.010                3.885
# std       1.284                    2.994            48.335            15.320              228.669
# min       1.000                 -463.890         -1578.700         -1858.486            -1325.000
# 25%       2.000                    0.003             0.002             0.017                0.908
# 50%       3.000                    0.050             0.030             0.123                1.045
# 75%       4.000                    0.130             0.078             0.289                1.204
# max       5.000                   94.280          9230.500          1031.911            29907.000
#
#        Operating_Income_to_Total_Asset_ratio  (inventory∗365)/cost_of_products_sold  \
# count                              43397.000                              43108.000
# mean                                   0.093                                357.749
# std                                    5.713                              33128.016
# min                                 -517.480                                -96.110
# 25%                                    0.006                                 16.226
# 50%                                    0.060                                 38.130
# 75%                                    0.151                                 70.340
# max                                  649.230                            6080000.000
#
#        working_capital  Working_Capital_to_Total_Assets_Ratio  Defensive_Interval_Ratio  \
# count        43404.000                              43397.000                 43316.000
# mean          7672.346                                  0.114                  -385.348
# std          70053.490                                  5.439                 61227.968
# min       -1810000.000                               -479.960             -11900000.000
# 25%             27.554                                  0.022                   -49.080
# 50%           1088.350                                  0.197                    -1.034
# 75%           4993.325                                  0.403                    50.634
# max        6120000.000                                 28.336               1250100.000
#
#        Debt_Coverage_Ratio  Equity_to_Total_Assets_Ratio  Total_Liabilities/total_assets  \
# count            37652.000                     43397.000                       43397.000
# mean              1346.821                         0.627                           0.590
# std              44286.556                        14.671                           5.843
# min            -290620.747                      -479.910                        -430.870
# 25%                  0.096                         0.295                           0.269
# 50%                  0.999                         0.506                           0.472
# 75%                  5.943                         0.709                           0.688
# max            6251825.424                      1099.500                         480.960
#
#        Financial_Leverage  Financial_expense_to_operating  Interest_to_cash  Interest_to_Sales  \
# count           43393.000                       37635.000         23511.000          43277.000
# mean                4.808                           0.347           617.736              0.021
# std               162.590                         316.997        115662.865              1.949
# min             -2418.731                      -59197.589      -5855701.082           -181.810
# 25%                 1.318                           0.004             0.015              0.000
# 50%                 1.823                           0.248             0.257              0.000
# 75%                 2.907                           1.279             1.585              0.007
# max             27027.027                        5554.244      15987106.466            301.300
#
#        Cash_to_Financial_Expense  Cash_to_assets  (receivables∗365)/sales  \
# count                  37567.000       43270.000                43278.000
# mean                    1602.862          -1.694                  831.035
# std                    84176.481         331.746               110050.165
# min                 -5282808.239      -62701.320              -116000.000
# 25%                        0.089           0.006                   34.878
# 50%                        0.717           0.037                   54.767
# 75%                        4.571           0.130                   80.522
# max                 13597750.957       12643.204             22584000.000
#
#        total_costs/total_sales  Cash_conversion_cycle  \
# count                43321.000              42986.000
# mean                    30.026               1181.687
# std                   5334.454             115187.014
# min                   -198.690            -116000.365
# 25%                      0.875                 68.206
# 50%                      0.951                102.656
# 75%                      0.993                147.330
# max                1108300.000           22584006.984
#
#        (short-term_liabilities∗365)/cost_of_products_sold)
# count                                            43104.000
# mean                                                 6.478
# std                                                639.887
# min                                                -25.467
# 25%                                                  0.127
# 50%                                                  0.214
# 75%                                                  0.350
# max                                              88433.000

# %%
#exterime outliers are detected with the first analysis. will use a range with a multiper to remove the exterme outliers.

# %%
Bankrupt_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43405 entries, 0 to 43404
# Data columns (total 25 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   year                                                 43405 non-null  int64
#  1   net_profit/total assets                              43397 non-null  float64
#  2   net_profit/sales                                     43278 non-null  float64
#  3   Return_On_equity                                     43266 non-null  float64
#  4   sales(n)/sales(n-1)                                  37551 non-null  float64
#  5   Operating_Income_to_Total_Asset_ratio                43397 non-null  float64
#  6   (inventory∗365)/cost_of_products_sold                43108 non-null  float64
#  7   working_capital                                      43404 non-null  float64
#  8   Working_Capital_to_Total_Assets_Ratio                43397 non-null  float64
#  9   working_capital_indicator                            43405 non-null  category
#  10  Defensive_Interval_Ratio                             43316 non-null  float64
#  11  Debt_Coverage_Ratio                                  37652 non-null  float64
#  12  Equity_to_Total_Assets_Ratio                         43397 non-null  float64
#  13  Total_Liabilities/total_assets                       43397 non-null  float64
#  14  Financial_Leverage                                   43393 non-null  float64
#  15  Financial_expense_to_operating                       37635 non-null  float64
#  16  Interest_to_cash                                     23511 non-null  float64
#  17  Interest_to_Sales                                    43277 non-null  float64
#  18  Cash_to_Financial_Expense                            37567 non-null  float64
#  19  Cash_to_assets                                       43270 non-null  float64
#  20  (receivables∗365)/sales                              43278 non-null  float64
#  21  total_costs/total_sales                              43321 non-null  float64
#  22  Cash_conversion_cycle                                42986 non-null  float64
#  23  (short-term_liabilities∗365)/cost_of_products_sold)  43104 non-null  float64
#  24  class                                                43405 non-null  category
# dtypes: category(2), float64(22), int64(1)
# memory usage: 7.7 MB

# %%
#adjusting for outliers
numeric_cols = Bankrupt_model.select_dtypes(include=[float, int]).columns
numeric_cols
# Out:
# Index(['year', 'net_profit/total assets', 'net_profit/sales', 'Return_On_equity',
#        'sales(n)/sales(n-1)', 'Operating_Income_to_Total_Asset_ratio',
#        '(inventory∗365)/cost_of_products_sold', 'working_capital',
#        'Working_Capital_to_Total_Assets_Ratio', 'Defensive_Interval_Ratio', 'Debt_Coverage_Ratio',
#        'Equity_to_Total_Assets_Ratio', 'Total_Liabilities/total_assets', 'Financial_Leverage',
#        'Financial_expense_to_operating', 'Interest_to_cash', 'Interest_to_Sales',
#        'Cash_to_Financial_Expense', 'Cash_to_assets', '(receivables∗365)/sales',
#        'total_costs/total_sales', 'Cash_conversion_cycle',
#        '(short-term_liabilities∗365)/cost_of_products_sold)'],
#       dtype='object')

# %%
#adjusting for outliers
numeric_cols = Bankrupt_model.select_dtypes(include=[float, int]).columns
# Calculate Q1, Q3, and IQR for each column
Q1 = Bankrupt_model[numeric_cols].quantile(0.25)
Q3 = Bankrupt_model[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 5 * IQR
upper_bound = Q3 + 5 * IQR

# Create a boolean DataFrame indicating whether each value is an outlier
outliers = (Bankrupt_model[numeric_cols] < lower_bound) | (Bankrupt_model[numeric_cols] > upper_bound)

# Filter rows that contain any outliers
rows_with_outliers = outliers.any(axis=1)
Bankruptcleaned_model = Bankrupt_model[~rows_with_outliers]

Bankruptcleaned_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22828 entries, 3 to 43404
# Data columns (total 25 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   year                                                 22828 non-null  int64
#  1   net_profit/total assets                              22824 non-null  float64
#  2   net_profit/sales                                     22812 non-null  float64
#  3   Return_On_equity                                     22806 non-null  float64
#  4   sales(n)/sales(n-1)                                  20141 non-null  float64
#  5   Operating_Income_to_Total_Asset_ratio                22824 non-null  float64
#  6   (inventory∗365)/cost_of_products_sold                22822 non-null  float64
#  7   working_capital                                      22827 non-null  float64
#  8   Working_Capital_to_Total_Assets_Ratio                22824 non-null  float64
#  9   working_capital_indicator                            22828 non-null  category
#  10  Defensive_Interval_Ratio                             22820 non-null  float64
#  11  Debt_Coverage_Ratio                                  20657 non-null  float64
#  12  Equity_to_Total_Assets_Ratio                         22824 non-null  float64
#  13  Total_Liabilities/total_assets                       22824 non-null  float64
#  14  Financial_Leverage                                   22822 non-null  float64
#  15  Financial_expense_to_operating                       20656 non-null  float64
#  16  Interest_to_cash                                     10983 non-null  float64
#  17  Interest_to_Sales                                    22812 non-null  float64
#  18  Cash_to_Financial_Expense                            20649 non-null  float64
#  19  Cash_to_assets                                       22808 non-null  float64
#  20  (receivables∗365)/sales                              22812 non-null  float64
#  21  total_costs/total_sales                              22813 non-null  float64
#  22  Cash_conversion_cycle                                22810 non-null  float64
#  23  (short-term_liabilities∗365)/cost_of_products_sold)  22820 non-null  float64
#  24  class                                                22828 non-null  category
# dtypes: category(2), float64(22), int64(1)
# memory usage: 4.2 MB

# %%
print(len(Bankrupt_model))
print(len(Bankruptcleaned_model))
# Out:
# 43405
# 22828

# %%
Bankruptcleaned_model.describe()
# Out:
#            year  net_profit/total assets  net_profit/sales  Return_On_equity  sales(n)/sales(n-1)  \
# count 22828.000                22824.000         22812.000         22806.000            20141.000
# mean      2.917                    0.072             0.040             0.152                1.079
# std       1.302                    0.126             0.079             0.286                0.281
# min       1.000                   -0.618            -0.376            -1.338                0.000
# 25%       2.000                    0.015             0.009             0.036                0.921
# 50%       3.000                    0.059             0.034             0.129                1.052
# 75%       4.000                    0.127             0.074             0.269                1.205
# max       5.000                    0.755             0.457             1.645                2.677
#
#        Operating_Income_to_Total_Asset_ratio  (inventory∗365)/cost_of_products_sold  \
# count                              22824.000                              22822.000
# mean                                   0.087                                 51.211
# std                                    0.140                                 45.929
# min                                   -0.610                                 -0.077
# 25%                                    0.020                                 19.042
# 50%                                    0.071                                 40.139
# 75%                                    0.149                                 69.271
# max                                    0.865                                338.770
#
#        working_capital  Working_Capital_to_Total_Assets_Ratio  Defensive_Interval_Ratio  \
# count        22827.000                              22824.000                 22820.000
# mean          3458.127                                  0.210                    -1.419
# std           6715.798                                  0.265                    92.910
# min         -24790.000                                 -1.865                  -541.630
# 25%            133.525                                  0.048                   -39.894
# 50%           1397.000                                  0.196                    -3.194
# 75%           5254.250                                  0.374                    34.880
# max          29818.000                                  1.000                   547.670
#
#        Debt_Coverage_Ratio  Equity_to_Total_Assets_Ratio  Total_Liabilities/total_assets  \
# count            20657.000                     22824.000                       22824.000
# mean                 3.086                         0.501                           0.478
# std                  6.584                         0.265                           0.267
# min                -29.039                        -1.763                           0.000
# 25%                  0.305                         0.341                           0.289
# 50%                  1.052                         0.511                           0.464
# 75%                  3.760                         0.684                           0.640
# max                 35.132                         1.000                           2.743
#
#        Financial_Leverage  Financial_expense_to_operating  Interest_to_cash  Interest_to_Sales  \
# count           22822.000                       20656.000         10983.000          22812.000
# mean                2.326                           0.858             0.906              0.004
# std                 1.704                           1.809             1.703              0.008
# min                -6.619                          -6.357            -7.777             -0.036
# 25%                 1.427                           0.086             0.061              0.000
# 50%                 1.906                           0.455             0.279              0.000
# 75%                 2.801                           1.404             1.045              0.006
# max                10.813                           7.649             9.409              0.043
#
#        Cash_to_Financial_Expense  Cash_to_assets  (receivables∗365)/sales  \
# count                  20649.000       22808.000                22812.000
# mean                       2.481           0.081                   60.890
# std                        4.627           0.119                   37.957
# min                      -22.112          -0.441                    0.000
# 25%                        0.129           0.008                   35.664
# 50%                        0.661           0.036                   54.087
# 75%                        2.455           0.110                   76.998
# max                       26.942           0.746                  307.250
#
#        total_costs/total_sales  Cash_conversion_cycle  \
# count                22813.000              22810.000
# mean                     0.936                111.868
# std                      0.102                 60.464
# min                      0.307                 -0.167
# 25%                      0.895                 70.568
# 50%                      0.949                101.976
# 75%                      0.985                140.584
# max                      1.576                537.226
#
#        (short-term_liabilities∗365)/cost_of_products_sold)
# count                                            22820.000
# mean                                                 0.249
# std                                                  0.175
# min                                                 -0.698
# 25%                                                  0.130
# 50%                                                  0.210
# 75%                                                  0.318
# max                                                  1.460

# %%
Bankruptcleaned_model.corr()
# Out:
#                                                       year  net_profit/total assets  \
# year                                                 1.000                   -0.099
# net_profit/total assets                             -0.099                    1.000
# net_profit/sales                                    -0.065                    0.827
# Return_On_equity                                    -0.096                    0.692
# sales(n)/sales(n-1)                                  0.017                    0.253
# Operating_Income_to_Total_Asset_ratio               -0.106                    0.986
# (inventory∗365)/cost_of_products_sold                0.032                   -0.121
# working_capital                                      0.031                    0.180
# Working_Capital_to_Total_Assets_Ratio                0.030                    0.329
# working_capital_indicator                            0.017                    0.209
# Defensive_Interval_Ratio                             0.028                    0.259
# Debt_Coverage_Ratio                                 -0.046                    0.526
# Equity_to_Total_Assets_Ratio                         0.016                    0.291
# Total_Liabilities/total_assets                      -0.016                   -0.282
# Financial_Leverage                                  -0.034                   -0.082
# Financial_expense_to_operating                       0.006                    0.060
# Interest_to_cash                                     0.003                   -0.076
# Interest_to_Sales                                    0.033                   -0.103
# Cash_to_Financial_Expense                            0.027                    0.101
# Cash_to_assets                                       0.004                    0.228
# (receivables∗365)/sales                              0.085                   -0.064
# total_costs/total_sales                              0.051                   -0.566
# Cash_conversion_cycle                                0.077                   -0.132
# (short-term_liabilities∗365)/cost_of_products_sold)  0.024                   -0.262
# class                                                0.020                   -0.132
#
#                                                      net_profit/sales  Return_On_equity  \
# year                                                           -0.065            -0.096
# net_profit/total assets                                         0.827             0.692
# net_profit/sales                                                1.000             0.582
# Return_On_equity                                                0.582             1.000
# sales(n)/sales(n-1)                                             0.220             0.251
# Operating_Income_to_Total_Asset_ratio                           0.811             0.688
# (inventory∗365)/cost_of_products_sold                          -0.038            -0.122
# working_capital                                                 0.232             0.065
# Working_Capital_to_Total_Assets_Ratio                           0.284             0.088
# working_capital_indicator                                       0.203             0.074
# Defensive_Interval_Ratio                                        0.312             0.090
# Debt_Coverage_Ratio                                             0.471             0.385
# Equity_to_Total_Assets_Ratio                                    0.311            -0.040
# Total_Liabilities/total_assets                                 -0.307             0.042
# Financial_Leverage                                             -0.105            -0.041
# Financial_expense_to_operating                                  0.068             0.087
# Interest_to_cash                                               -0.068            -0.032
# Interest_to_Sales                                              -0.080            -0.049
# Cash_to_Financial_Expense                                       0.099             0.038
# Cash_to_assets                                                  0.192             0.117
# (receivables∗365)/sales                                         0.027            -0.035
# total_costs/total_sales                                        -0.673            -0.383
# Cash_conversion_cycle                                          -0.011            -0.114
# (short-term_liabilities∗365)/cost_of_products_sold)            -0.188            -0.092
# class                                                          -0.140            -0.087
#
#                                                      sales(n)/sales(n-1)  \
# year                                                               0.017
# net_profit/total assets                                            0.253
# net_profit/sales                                                   0.220
# Return_On_equity                                                   0.251
# sales(n)/sales(n-1)                                                1.000
# Operating_Income_to_Total_Asset_ratio                              0.260
# (inventory∗365)/cost_of_products_sold                             -0.072
# working_capital                                                    0.034
# Working_Capital_to_Total_Assets_Ratio                             -0.024
# working_capital_indicator                                          0.019
# Defensive_Interval_Ratio                                          -0.027
# Debt_Coverage_Ratio                                                0.159
# Equity_to_Total_Assets_Ratio                                      -0.086
# Total_Liabilities/total_assets                                     0.083
# Financial_Leverage                                                 0.084
# Financial_expense_to_operating                                     0.052
# Interest_to_cash                                                  -0.001
# Interest_to_Sales                                                 -0.036
# Cash_to_Financial_Expense                                         -0.026
# Cash_to_assets                                                    -0.012
# (receivables∗365)/sales                                           -0.025
# total_costs/total_sales                                           -0.179
# Cash_conversion_cycle                                             -0.070
# (short-term_liabilities∗365)/cost_of_products_sold)                0.003
# class                                                             -0.035
#
#                                                      Operating_Income_to_Total_Asset_ratio  \
# year                                                                                -0.106
# net_profit/total assets                                                              0.986
# net_profit/sales                                                                     0.811
# Return_On_equity                                                                     0.688
# sales(n)/sales(n-1)                                                                  0.260
# Operating_Income_to_Total_Asset_ratio                                                1.000
# (inventory∗365)/cost_of_products_sold                                               -0.131
# working_capital                                                                      0.187
# Working_Capital_to_Total_Assets_Ratio                                                0.342
# working_capital_indicator                                                            0.214
# Defensive_Interval_Ratio                                                             0.269
# Debt_Coverage_Ratio                                                                  0.526
# Equity_to_Total_Assets_Ratio                                                         0.291
# Total_Liabilities/total_assets                                                      -0.283
# Financial_Leverage                                                                  -0.091
# Financial_expense_to_operating                                                       0.052
# Interest_to_cash                                                                    -0.087
# Interest_to_Sales                                                                   -0.113
# Cash_to_Financial_Expense                                                            0.107
# Cash_to_assets                                                                       0.250
# (receivables∗365)/sales                                                             -0.068
# total_costs/total_sales                                                             -0.566
# Cash_conversion_cycle                                                               -0.141
# (short-term_liabilities∗365)/cost_of_products_sold)                                 -0.272
# class                                                                               -0.129
#
#                                                      (inventory∗365)/cost_of_products_sold  \
# year                                                                                 0.032
# net_profit/total assets                                                             -0.121
# net_profit/sales                                                                    -0.038
# Return_On_equity                                                                    -0.122
# sales(n)/sales(n-1)                                                                 -0.072
# Operating_Income_to_Total_Asset_ratio                                               -0.131
# (inventory∗365)/cost_of_products_sold                                                1.000
# working_capital                                                                      0.149
# Working_Capital_to_Total_Assets_Ratio                                                0.166
# working_capital_indicator                                                            0.134
# Defensive_Interval_Ratio                                                            -0.201
# Debt_Coverage_Ratio                                                                 -0.061
# Equity_to_Total_Assets_Ratio                                                         0.045
# Total_Liabilities/total_assets                                                      -0.041
# Financial_Leverage                                                                  -0.019
# Financial_expense_to_operating                                                      -0.027
# Interest_to_cash                                                                     0.054
# Interest_to_Sales                                                                    0.096
# Cash_to_Financial_Expense                                                           -0.099
# Cash_to_assets                                                                      -0.182
# (receivables∗365)/sales                                                              0.033
# total_costs/total_sales                                                             -0.118
# Cash_conversion_cycle                                                                0.780
# (short-term_liabilities∗365)/cost_of_products_sold)                                  0.312
# class                                                                                0.002
#
#                                                      working_capital  \
# year                                                           0.031
# net_profit/total assets                                        0.180
# net_profit/sales                                               0.232
# Return_On_equity                                               0.065
# sales(n)/sales(n-1)                                            0.034
# Operating_Income_to_Total_Asset_ratio                          0.187
# (inventory∗365)/cost_of_products_sold                          0.149
# working_capital                                                1.000
# Working_Capital_to_Total_Assets_Ratio                          0.429
# working_capital_indicator                                      0.455
# Defensive_Interval_Ratio                                       0.336
# Debt_Coverage_Ratio                                           -0.016
# Equity_to_Total_Assets_Ratio                                   0.322
# Total_Liabilities/total_assets                                -0.354
# Financial_Leverage                                            -0.181
# Financial_expense_to_operating                                 0.086
# Interest_to_cash                                              -0.078
# Interest_to_Sales                                             -0.156
# Cash_to_Financial_Expense                                     -0.022
# Cash_to_assets                                                 0.159
# (receivables∗365)/sales                                        0.106
# total_costs/total_sales                                       -0.138
# Cash_conversion_cycle                                          0.180
# (short-term_liabilities∗365)/cost_of_products_sold)           -0.266
# class                                                         -0.081
#
#                                                      Working_Capital_to_Total_Assets_Ratio  \
# year                                                                                 0.030
# net_profit/total assets                                                              0.329
# net_profit/sales                                                                     0.284
# Return_On_equity                                                                     0.088
# sales(n)/sales(n-1)                                                                 -0.024
# Operating_Income_to_Total_Asset_ratio                                                0.342
# (inventory∗365)/cost_of_products_sold                                                0.166
# working_capital                                                                      0.429
# Working_Capital_to_Total_Assets_Ratio                                                1.000
# working_capital_indicator                                                            0.640
# Defensive_Interval_Ratio                                                             0.613
# Debt_Coverage_Ratio                                                                  0.196
# Equity_to_Total_Assets_Ratio                                                         0.645
# Total_Liabilities/total_assets                                                      -0.637
# Financial_Leverage                                                                  -0.228
# Financial_expense_to_operating                                                      -0.003
# Interest_to_cash                                                                    -0.177
# Interest_to_Sales                                                                   -0.147
# Cash_to_Financial_Expense                                                            0.255
# Cash_to_assets                                                                       0.445
# (receivables∗365)/sales                                                              0.110
# total_costs/total_sales                                                             -0.217
# Cash_conversion_cycle                                                                0.197
# (short-term_liabilities∗365)/cost_of_products_sold)                                 -0.540
# class                                                                               -0.114
#
#                                                      working_capital_indicator  \
# year                                                                     0.017
# net_profit/total assets                                                  0.209
# net_profit/sales                                                         0.203
# Return_On_equity                                                         0.074
# sales(n)/sales(n-1)                                                      0.019
# Operating_Income_to_Total_Asset_ratio                                    0.214
# (inventory∗365)/cost_of_products_sold                                    0.134
# working_capital                                                          0.455
# Working_Capital_to_Total_Assets_Ratio                                    0.640
# working_capital_indicator                                                1.000
# Defensive_Interval_Ratio                                                 0.419
# Debt_Coverage_Ratio                                                      0.137
# Equity_to_Total_Assets_Ratio                                             0.420
# Total_Liabilities/total_assets                                          -0.418
# Financial_Leverage                                                      -0.182
# Financial_expense_to_operating                                           0.020
# Interest_to_cash                                                        -0.129
# Interest_to_Sales                                                       -0.092
# Cash_to_Financial_Expense                                                0.144
# Cash_to_assets                                                           0.203
# (receivables∗365)/sales                                                  0.112
# total_costs/total_sales                                                 -0.154
# Cash_conversion_cycle                                                    0.173
# (short-term_liabilities∗365)/cost_of_products_sold)                     -0.389
# class                                                                   -0.111
#
#                                                      Defensive_Interval_Ratio  \
# year                                                                    0.028
# net_profit/total assets                                                 0.259
# net_profit/sales                                                        0.312
# Return_On_equity                                                        0.090
# sales(n)/sales(n-1)                                                    -0.027
# Operating_Income_to_Total_Asset_ratio                                   0.269
# (inventory∗365)/cost_of_products_sold                                  -0.201
# working_capital                                                         0.336
# Working_Capital_to_Total_Assets_Ratio                                   0.613
# working_capital_indicator                                               0.419
# Defensive_Interval_Ratio                                                1.000
# Debt_Coverage_Ratio                                                     0.158
# Equity_to_Total_Assets_Ratio                                            0.485
# Total_Liabilities/total_assets                                         -0.486
# Financial_Leverage                                                     -0.226
# Financial_expense_to_operating                                         -0.002
# Interest_to_cash                                                       -0.157
# Interest_to_Sales                                                      -0.126
# Cash_to_Financial_Expense                                               0.282
# Cash_to_assets                                                          0.466
# (receivables∗365)/sales                                                 0.194
# total_costs/total_sales                                                -0.185
# Cash_conversion_cycle                                                  -0.029
# (short-term_liabilities∗365)/cost_of_products_sold)                    -0.559
# class                                                                  -0.085
#
#                                                      Debt_Coverage_Ratio  \
# year                                                              -0.046
# net_profit/total assets                                            0.526
# net_profit/sales                                                   0.471
# Return_On_equity                                                   0.385
# sales(n)/sales(n-1)                                                0.159
# Operating_Income_to_Total_Asset_ratio                              0.526
# (inventory∗365)/cost_of_products_sold                             -0.061
# working_capital                                                   -0.016
# Working_Capital_to_Total_Assets_Ratio                              0.196
# working_capital_indicator                                          0.137
# Defensive_Interval_Ratio                                           0.158
# Debt_Coverage_Ratio                                                1.000
# Equity_to_Total_Assets_Ratio                                       0.175
# Total_Liabilities/total_assets                                    -0.142
# Financial_Leverage                                                -0.065
# Financial_expense_to_operating                                    -0.138
# Interest_to_cash                                                  -0.135
# Interest_to_Sales                                                 -0.027
# Cash_to_Financial_Expense                                          0.401
# Cash_to_assets                                                     0.077
# (receivables∗365)/sales                                            0.001
# total_costs/total_sales                                           -0.418
# Cash_conversion_cycle                                             -0.046
# (short-term_liabilities∗365)/cost_of_products_sold)               -0.153
# class                                                             -0.063
#
#                                                      Equity_to_Total_Assets_Ratio  \
# year                                                                        0.016
# net_profit/total assets                                                     0.291
# net_profit/sales                                                            0.311
# Return_On_equity                                                           -0.040
# sales(n)/sales(n-1)                                                        -0.086
# Operating_Income_to_Total_Asset_ratio                                       0.291
# (inventory∗365)/cost_of_products_sold                                       0.045
# working_capital                                                             0.322
# Working_Capital_to_Total_Assets_Ratio                                       0.645
# working_capital_indicator                                                   0.420
# Defensive_Interval_Ratio                                                    0.485
# Debt_Coverage_Ratio                                                         0.175
# Equity_to_Total_Assets_Ratio                                                1.000
# Total_Liabilities/total_assets                                             -0.981
# Financial_Leverage                                                         -0.365
# Financial_expense_to_operating                                              0.000
# Interest_to_cash                                                           -0.141
# Interest_to_Sales                                                          -0.175
# Cash_to_Financial_Expense                                                   0.170
# Cash_to_assets                                                              0.259
# (receivables∗365)/sales                                                    -0.049
# total_costs/total_sales                                                    -0.231
# Cash_conversion_cycle                                                       0.006
# (short-term_liabilities∗365)/cost_of_products_sold)                        -0.507
# class                                                                      -0.122
#
#                                                      Total_Liabilities/total_assets  \
# year                                                                         -0.016
# net_profit/total assets                                                      -0.282
# net_profit/sales                                                             -0.307
# Return_On_equity                                                              0.042
# sales(n)/sales(n-1)                                                           0.083
# Operating_Income_to_Total_Asset_ratio                                        -0.283
# (inventory∗365)/cost_of_products_sold                                        -0.041
# working_capital                                                              -0.354
# Working_Capital_to_Total_Assets_Ratio                                        -0.637
# working_capital_indicator                                                    -0.418
# Defensive_Interval_Ratio                                                     -0.486
# Debt_Coverage_Ratio                                                          -0.142
# Equity_to_Total_Assets_Ratio                                                 -0.981
# Total_Liabilities/total_assets                                                1.000
# Financial_Leverage                                                            0.360
# Financial_expense_to_operating                                               -0.027
# Interest_to_cash                                                              0.141
# Interest_to_Sales                                                             0.214
# Cash_to_Financial_Expense                                                    -0.137
# Cash_to_assets                                                               -0.256
# (receivables∗365)/sales                                                       0.053
# total_costs/total_sales                                                       0.209
# Cash_conversion_cycle                                                         0.000
# (short-term_liabilities∗365)/cost_of_products_sold)                           0.509
# class                                                                         0.122
#
#                                                      Financial_Leverage  \
# year                                                             -0.034
# net_profit/total assets                                          -0.082
# net_profit/sales                                                 -0.105
# Return_On_equity                                                 -0.041
# sales(n)/sales(n-1)                                               0.084
# Operating_Income_to_Total_Asset_ratio                            -0.091
# (inventory∗365)/cost_of_products_sold                            -0.019
# working_capital                                                  -0.181
# Working_Capital_to_Total_Assets_Ratio                            -0.228
# working_capital_indicator                                        -0.182
# Defensive_Interval_Ratio                                         -0.226
# Debt_Coverage_Ratio                                              -0.065
# Equity_to_Total_Assets_Ratio                                     -0.365
# Total_Liabilities/total_assets                                    0.360
# Financial_Leverage                                                1.000
# Financial_expense_to_operating                                    0.067
# Interest_to_cash                                                  0.104
# Interest_to_Sales                                                 0.113
# Cash_to_Financial_Expense                                        -0.091
# Cash_to_assets                                                   -0.155
# (receivables∗365)/sales                                           0.073
# total_costs/total_sales                                           0.067
# Cash_conversion_cycle                                             0.030
# (short-term_liabilities∗365)/cost_of_products_sold)               0.256
# class                                                             0.072
#
#                                                      Financial_expense_to_operating  \
# year                                                                          0.006
# net_profit/total assets                                                       0.060
# net_profit/sales                                                              0.068
# Return_On_equity                                                              0.087
# sales(n)/sales(n-1)                                                           0.052
# Operating_Income_to_Total_Asset_ratio                                         0.052
# (inventory∗365)/cost_of_products_sold                                        -0.027
# working_capital                                                               0.086
# Working_Capital_to_Total_Assets_Ratio                                        -0.003
# working_capital_indicator                                                     0.020
# Defensive_Interval_Ratio                                                     -0.002
# Debt_Coverage_Ratio                                                          -0.138
# Equity_to_Total_Assets_Ratio                                                  0.000
# Total_Liabilities/total_assets                                               -0.027
# Financial_Leverage                                                            0.067
# Financial_expense_to_operating                                                1.000
# Interest_to_cash                                                              0.067
# Interest_to_Sales                                                            -0.110
# Cash_to_Financial_Expense                                                    -0.154
# Cash_to_assets                                                               -0.022
# (receivables∗365)/sales                                                      -0.033
# total_costs/total_sales                                                      -0.018
# Cash_conversion_cycle                                                        -0.041
# (short-term_liabilities∗365)/cost_of_products_sold)                          -0.045
# class                                                                        -0.044
#
#                                                      Interest_to_cash  Interest_to_Sales  \
# year                                                            0.003              0.033
# net_profit/total assets                                        -0.076             -0.103
# net_profit/sales                                               -0.068             -0.080
# Return_On_equity                                               -0.032             -0.049
# sales(n)/sales(n-1)                                            -0.001             -0.036
# Operating_Income_to_Total_Asset_ratio                          -0.087             -0.113
# (inventory∗365)/cost_of_products_sold                           0.054              0.096
# working_capital                                                -0.078             -0.156
# Working_Capital_to_Total_Assets_Ratio                          -0.177             -0.147
# working_capital_indicator                                      -0.129             -0.092
# Defensive_Interval_Ratio                                       -0.157             -0.126
# Debt_Coverage_Ratio                                            -0.135             -0.027
# Equity_to_Total_Assets_Ratio                                   -0.141             -0.175
# Total_Liabilities/total_assets                                  0.141              0.214
# Financial_Leverage                                              0.104              0.113
# Financial_expense_to_operating                                  0.067             -0.110
# Interest_to_cash                                                1.000              0.329
# Interest_to_Sales                                               0.329              1.000
# Cash_to_Financial_Expense                                      -0.315             -0.018
# Cash_to_assets                                                 -0.304             -0.095
# (receivables∗365)/sales                                         0.027              0.056
# total_costs/total_sales                                         0.051             -0.031
# Cash_conversion_cycle                                           0.058              0.108
# (short-term_liabilities∗365)/cost_of_products_sold)             0.116              0.181
# class                                                          -0.069              0.039
#
#                                                      Cash_to_Financial_Expense  Cash_to_assets  \
# year                                                                     0.027           0.004
# net_profit/total assets                                                  0.101           0.228
# net_profit/sales                                                         0.099           0.192
# Return_On_equity                                                         0.038           0.117
# sales(n)/sales(n-1)                                                     -0.026          -0.012
# Operating_Income_to_Total_Asset_ratio                                    0.107           0.250
# (inventory∗365)/cost_of_products_sold                                   -0.099          -0.182
# working_capital                                                         -0.022           0.159
# Working_Capital_to_Total_Assets_Ratio                                    0.255           0.445
# working_capital_indicator                                                0.144           0.203
# Defensive_Interval_Ratio                                                 0.282           0.466
# Debt_Coverage_Ratio                                                      0.401           0.077
# Equity_to_Total_Assets_Ratio                                             0.170           0.259
# Total_Liabilities/total_assets                                          -0.137          -0.256
# Financial_Leverage                                                      -0.091          -0.155
# Financial_expense_to_operating                                          -0.154          -0.022
# Interest_to_cash                                                        -0.315          -0.304
# Interest_to_Sales                                                       -0.018          -0.095
# Cash_to_Financial_Expense                                                1.000           0.505
# Cash_to_assets                                                           0.505           1.000
# (receivables∗365)/sales                                                 -0.038          -0.145
# total_costs/total_sales                                                 -0.064          -0.126
# Cash_conversion_cycle                                                   -0.098          -0.229
# (short-term_liabilities∗365)/cost_of_products_sold)                     -0.151          -0.257
# class                                                                   -0.033          -0.072
#
#                                                      (receivables∗365)/sales  \
# year                                                                   0.085
# net_profit/total assets                                               -0.064
# net_profit/sales                                                       0.027
# Return_On_equity                                                      -0.035
# sales(n)/sales(n-1)                                                   -0.025
# Operating_Income_to_Total_Asset_ratio                                 -0.068
# (inventory∗365)/cost_of_products_sold                                  0.033
# working_capital                                                        0.106
# Working_Capital_to_Total_Assets_Ratio                                  0.110
# working_capital_indicator                                              0.112
# Defensive_Interval_Ratio                                               0.194
# Debt_Coverage_Ratio                                                    0.001
# Equity_to_Total_Assets_Ratio                                          -0.049
# Total_Liabilities/total_assets                                         0.053
# Financial_Leverage                                                     0.073
# Financial_expense_to_operating                                        -0.033
# Interest_to_cash                                                       0.027
# Interest_to_Sales                                                      0.056
# Cash_to_Financial_Expense                                             -0.038
# Cash_to_assets                                                        -0.145
# (receivables∗365)/sales                                                1.000
# total_costs/total_sales                                               -0.038
# Cash_conversion_cycle                                                  0.652
# (short-term_liabilities∗365)/cost_of_products_sold)                    0.388
# class                                                                 -0.026
#
#                                                      total_costs/total_sales  \
# year                                                                   0.051
# net_profit/total assets                                               -0.566
# net_profit/sales                                                      -0.673
# Return_On_equity                                                      -0.383
# sales(n)/sales(n-1)                                                   -0.179
# Operating_Income_to_Total_Asset_ratio                                 -0.566
# (inventory∗365)/cost_of_products_sold                                 -0.118
# working_capital                                                       -0.138
# Working_Capital_to_Total_Assets_Ratio                                 -0.217
# working_capital_indicator                                             -0.154
# Defensive_Interval_Ratio                                              -0.185
# Debt_Coverage_Ratio                                                   -0.418
# Equity_to_Total_Assets_Ratio                                          -0.231
# Total_Liabilities/total_assets                                         0.209
# Financial_Leverage                                                     0.067
# Financial_expense_to_operating                                        -0.018
# Interest_to_cash                                                       0.051
# Interest_to_Sales                                                     -0.031
# Cash_to_Financial_Expense                                             -0.064
# Cash_to_assets                                                        -0.126
# (receivables∗365)/sales                                               -0.038
# total_costs/total_sales                                                1.000
# Cash_conversion_cycle                                                 -0.113
# (short-term_liabilities∗365)/cost_of_products_sold)                    0.001
# class                                                                  0.067
#
#                                                      Cash_conversion_cycle  \
# year                                                                 0.077
# net_profit/total assets                                             -0.132
# net_profit/sales                                                    -0.011
# Return_On_equity                                                    -0.114
# sales(n)/sales(n-1)                                                 -0.070
# Operating_Income_to_Total_Asset_ratio                               -0.141
# (inventory∗365)/cost_of_products_sold                                0.780
# working_capital                                                      0.180
# Working_Capital_to_Total_Assets_Ratio                                0.197
# working_capital_indicator                                            0.173
# Defensive_Interval_Ratio                                            -0.029
# Debt_Coverage_Ratio                                                 -0.046
# Equity_to_Total_Assets_Ratio                                         0.006
# Total_Liabilities/total_assets                                       0.000
# Financial_Leverage                                                   0.030
# Financial_expense_to_operating                                      -0.041
# Interest_to_cash                                                     0.058
# Interest_to_Sales                                                    0.108
# Cash_to_Financial_Expense                                           -0.098
# Cash_to_assets                                                      -0.229
# (receivables∗365)/sales                                              0.652
# total_costs/total_sales                                             -0.113
# Cash_conversion_cycle                                                1.000
# (short-term_liabilities∗365)/cost_of_products_sold)                  0.479
# class                                                               -0.015
#
#                                                      (short-term_liabilities∗365)/cost_of_products_sold)  \
# year                                                                                               0.024
# net_profit/total assets                                                                           -0.262
# net_profit/sales                                                                                  -0.188
# Return_On_equity                                                                                  -0.092
# sales(n)/sales(n-1)                                                                                0.003
# Operating_Income_to_Total_Asset_ratio                                                             -0.272
# (inventory∗365)/cost_of_products_sold                                                              0.312
# working_capital                                                                                   -0.266
# Working_Capital_to_Total_Assets_Ratio                                                             -0.540
# working_capital_indicator                                                                         -0.389
# Defensive_Interval_Ratio                                                                          -0.559
# Debt_Coverage_Ratio                                                                               -0.153
# Equity_to_Total_Assets_Ratio                                                                      -0.507
# Total_Liabilities/total_assets                                                                     0.509
# Financial_Leverage                                                                                 0.256
# Financial_expense_to_operating                                                                    -0.045
# Interest_to_cash                                                                                   0.116
# Interest_to_Sales                                                                                  0.181
# Cash_to_Financial_Expense                                                                         -0.151
# Cash_to_assets                                                                                    -0.257
# (receivables∗365)/sales                                                                            0.388
# total_costs/total_sales                                                                            0.001
# Cash_conversion_cycle                                                                              0.479
# (short-term_liabilities∗365)/cost_of_products_sold)                                                1.000
# class                                                                                              0.054
#
#                                                      class
# year                                                 0.020
# net_profit/total assets                             -0.132
# net_profit/sales                                    -0.140
# Return_On_equity                                    -0.087
# sales(n)/sales(n-1)                                 -0.035
# Operating_Income_to_Total_Asset_ratio               -0.129
# (inventory∗365)/cost_of_products_sold                0.002
# working_capital                                     -0.081
# Working_Capital_to_Total_Assets_Ratio               -0.114
# working_capital_indicator                           -0.111
# Defensive_Interval_Ratio                            -0.085
# Debt_Coverage_Ratio                                 -0.063
# Equity_to_Total_Assets_Ratio                        -0.122
# Total_Liabilities/total_assets                       0.122
# Financial_Leverage                                   0.072
# Financial_expense_to_operating                      -0.044
# Interest_to_cash                                    -0.069
# Interest_to_Sales                                    0.039
# Cash_to_Financial_Expense                           -0.033
# Cash_to_assets                                      -0.072
# (receivables∗365)/sales                             -0.026
# total_costs/total_sales                              0.067
# Cash_conversion_cycle                               -0.015
# (short-term_liabilities∗365)/cost_of_products_sold)  0.054
# class                                                1.000

# %%
corr_pairs_negative = Bankruptcleaned_model.corr().unstack().sort_values(ascending=False)
corr_pairs_negative = corr_pairs_negative[corr_pairs_negative < -0.4]
corr_pairs_negative = corr_pairs_negative[corr_pairs_negative < 1].drop_duplicates()
pd.DataFrame(corr_pairs_negative)
corr_pairs_negative
# Out:
# Total_Liabilities/total_assets                       working_capital_indicator                             -0.418
# total_costs/total_sales                              Debt_Coverage_Ratio                                   -0.418
# Total_Liabilities/total_assets                       Defensive_Interval_Ratio                              -0.486
# (short-term_liabilities∗365)/cost_of_products_sold)  Equity_to_Total_Assets_Ratio                          -0.507
#                                                      Working_Capital_to_Total_Assets_Ratio                 -0.540
# Defensive_Interval_Ratio                             (short-term_liabilities∗365)/cost_of_products_sold)   -0.559
# Operating_Income_to_Total_Asset_ratio                total_costs/total_sales                               -0.566
# total_costs/total_sales                              net_profit/total assets                               -0.566
# Total_Liabilities/total_assets                       Working_Capital_to_Total_Assets_Ratio                 -0.637
# net_profit/sales                                     total_costs/total_sales                               -0.673
# Total_Liabilities/total_assets                       Equity_to_Total_Assets_Ratio                          -0.981
# dtype: float64

# %%
for column in Bankruptcleaned_model.columns:
  countzero = (Bankruptcleaned_model[column] == 0).sum()
  print(f"{column} has {countzero} zero values")
# Out:
# year has 0 zero values
# net_profit/total assets has 70 zero values
# net_profit/sales has 66 zero values
# Return_On_equity has 65 zero values
# sales(n)/sales(n-1) has 4 zero values
# Operating_Income_to_Total_Asset_ratio has 9 zero values
# (inventory∗365)/cost_of_products_sold has 682 zero values
# working_capital has 2 zero values
# Working_Capital_to_Total_Assets_Ratio has 0 zero values
# working_capital_indicator has 3965 zero values
# Defensive_Interval_Ratio has 11 zero values
# Debt_Coverage_Ratio has 2 zero values
# Equity_to_Total_Assets_Ratio has 2 zero values
# Total_Liabilities/total_assets has 8 zero values
# Financial_Leverage has 0 zero values
# Financial_expense_to_operating has 1 zero values
# Interest_to_cash has 0 zero values
# Interest_to_Sales has 11828 zero values
# Cash_to_Financial_Expense has 0 zero values
# Cash_to_assets has 1 zero values
# (receivables∗365)/sales has 26 zero values
# total_costs/total_sales has 0 zero values
# Cash_conversion_cycle has 10 zero values
# (short-term_liabilities∗365)/cost_of_products_sold) has 23 zero values
# class has 21703 zero values

# %%
length=len(Bankruptcleaned_model['class'])
print(f"total number of rows is: {length}")
# Out:
# total number of rows is: 22828

# %%
nulls=Bankruptcleaned_model.isnull().sum()

# %%
nulls
# Out:
# year                                                       0
# net_profit/total assets                                    4
# net_profit/sales                                          16
# Return_On_equity                                          22
# sales(n)/sales(n-1)                                     2687
# Operating_Income_to_Total_Asset_ratio                      4
# (inventory∗365)/cost_of_products_sold                      6
# working_capital                                            1
# Working_Capital_to_Total_Assets_Ratio                      4
# working_capital_indicator                                  0
# Defensive_Interval_Ratio                                   8
# Debt_Coverage_Ratio                                     2171
# Equity_to_Total_Assets_Ratio                               4
# Total_Liabilities/total_assets                             4
# Financial_Leverage                                         6
# Financial_expense_to_operating                          2172
# Interest_to_cash                                       11845
# Interest_to_Sales                                         16
# Cash_to_Financial_Expense                               2179
# Cash_to_assets                                            20
# (receivables∗365)/sales                                   16
# total_costs/total_sales                                   15
# Cash_conversion_cycle                                     18
# (short-term_liabilities∗365)/cost_of_products_sold)        8
# class                                                      0
# dtype: int64

# %%
percentage_nulls=nulls/length*100
percentage_nulls
#to determine % of null per attribute. anything over 10% will be removed. The remainder will use random forest imputation.
# Out:
# year                                                   0.000
# net_profit/total assets                                0.018
# net_profit/sales                                       0.070
# Return_On_equity                                       0.096
# sales(n)/sales(n-1)                                   11.771
# Operating_Income_to_Total_Asset_ratio                  0.018
# (inventory∗365)/cost_of_products_sold                  0.026
# working_capital                                        0.004
# Working_Capital_to_Total_Assets_Ratio                  0.018
# working_capital_indicator                              0.000
# Defensive_Interval_Ratio                               0.035
# Debt_Coverage_Ratio                                    9.510
# Equity_to_Total_Assets_Ratio                           0.018
# Total_Liabilities/total_assets                         0.018
# Financial_Leverage                                     0.026
# Financial_expense_to_operating                         9.515
# Interest_to_cash                                      51.888
# Interest_to_Sales                                      0.070
# Cash_to_Financial_Expense                              9.545
# Cash_to_assets                                         0.088
# (receivables∗365)/sales                                0.070
# total_costs/total_sales                                0.066
# Cash_conversion_cycle                                  0.079
# (short-term_liabilities∗365)/cost_of_products_sold)    0.035
# class                                                  0.000
# dtype: float64

# %%
percentage_nulls[percentage_nulls>5]
# Out:
# sales(n)/sales(n-1)              11.771
# Debt_Coverage_Ratio               9.510
# Financial_expense_to_operating    9.515
# Interest_to_cash                 51.888
# Cash_to_Financial_Expense         9.545
# dtype: float64

# %%
Bankruptcleaned_model.drop(['sales(n)/sales(n-1)','Debt_Coverage_Ratio','Financial_expense_to_operating','Interest_to_cash','Cash_to_Financial_Expense'],axis=1,inplace=True)
# Out:
# <ipython-input-85-65fb679f6fe4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bankruptcleaned_model.drop(['sales(n)/sales(n-1)','Debt_Coverage_Ratio','Financial_expense_to_operating','Interest_to_cash','Cash_to_Financial_Expense'],axis=1,inplace=True)

# %%
Bankruptcleaned_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22828 entries, 3 to 43404
# Data columns (total 20 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   year                                                 22828 non-null  int64
#  1   net_profit/total assets                              22824 non-null  float64
#  2   net_profit/sales                                     22812 non-null  float64
#  3   Return_On_equity                                     22806 non-null  float64
#  4   Operating_Income_to_Total_Asset_ratio                22824 non-null  float64
#  5   (inventory∗365)/cost_of_products_sold                22822 non-null  float64
#  6   working_capital                                      22827 non-null  float64
#  7   Working_Capital_to_Total_Assets_Ratio                22824 non-null  float64
#  8   working_capital_indicator                            22828 non-null  category
#  9   Defensive_Interval_Ratio                             22820 non-null  float64
#  10  Equity_to_Total_Assets_Ratio                         22824 non-null  float64
#  11  Total_Liabilities/total_assets                       22824 non-null  float64
#  12  Financial_Leverage                                   22822 non-null  float64
#  13  Interest_to_Sales                                    22812 non-null  float64
#  14  Cash_to_assets                                       22808 non-null  float64
#  15  (receivables∗365)/sales                              22812 non-null  float64
#  16  total_costs/total_sales                              22813 non-null  float64
#  17  Cash_conversion_cycle                                22810 non-null  float64
#  18  (short-term_liabilities∗365)/cost_of_products_sold)  22820 non-null  float64
#  19  class                                                22828 non-null  category
# dtypes: category(2), float64(17), int64(1)
# memory usage: 3.4 MB

# %%
 nulls=Bankruptcleaned_model.isnull().sum()
 nulls
# Out:
# year                                                    0
# net_profit/total assets                                 4
# net_profit/sales                                       16
# Return_On_equity                                       22
# Operating_Income_to_Total_Asset_ratio                   4
# (inventory∗365)/cost_of_products_sold                   6
# working_capital                                         1
# Working_Capital_to_Total_Assets_Ratio                   4
# working_capital_indicator                               0
# Defensive_Interval_Ratio                                8
# Equity_to_Total_Assets_Ratio                            4
# Total_Liabilities/total_assets                          4
# Financial_Leverage                                      6
# Interest_to_Sales                                      16
# Cash_to_assets                                         20
# (receivables∗365)/sales                                16
# total_costs/total_sales                                15
# Cash_conversion_cycle                                  18
# (short-term_liabilities∗365)/cost_of_products_sold)     8
# class                                                   0
# dtype: int64

# %%
nulls/length*100
# Out:
# year                                                  0.000
# net_profit/total assets                               0.018
# net_profit/sales                                      0.070
# Return_On_equity                                      0.096
# Operating_Income_to_Total_Asset_ratio                 0.018
# (inventory∗365)/cost_of_products_sold                 0.026
# working_capital                                       0.004
# Working_Capital_to_Total_Assets_Ratio                 0.018
# working_capital_indicator                             0.000
# Defensive_Interval_Ratio                              0.035
# Equity_to_Total_Assets_Ratio                          0.018
# Total_Liabilities/total_assets                        0.018
# Financial_Leverage                                    0.026
# Interest_to_Sales                                     0.070
# Cash_to_assets                                        0.088
# (receivables∗365)/sales                               0.070
# total_costs/total_sales                               0.066
# Cash_conversion_cycle                                 0.079
# (short-term_liabilities∗365)/cost_of_products_sold)   0.035
# class                                                 0.000
# dtype: float64

# %%
#using 3 different methods of imputation to see which one works best
Bankrupt_modelMMM=Bankruptcleaned_model.copy()
Bankrupt_modelKNN=Bankruptcleaned_model.copy()
Bankrupt_modelRF=Bankruptcleaned_model.copy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import KNNImputer

# %%
# Columns with missing values in your bankrupt_model dataset
columns_with_missing = [
    'net_profit/total assets', 'net_profit/sales', 'Return_On_equity',
    'Operating_Income_to_Total_Asset_ratio',
    '(inventory∗365)/cost_of_products_sold', 'working_capital',
    'Working_Capital_to_Total_Assets_Ratio', 'working_capital_indicator',
    'Defensive_Interval_Ratio', 'Equity_to_Total_Assets_Ratio',
    'Total_Liabilities/total_assets', 'Financial_Leverage',
    'Interest_to_Sales', 'Cash_to_assets', '(receivables∗365)/sales',
    'total_costs/total_sales', 'Cash_conversion_cycle',
    '(short-term_liabilities∗365)/cost_of_products_sold)'
]

# %%
# Perform imputation (example using SimpleImputer with mean)
imputer = SimpleImputer(strategy='mean')
Bankrupt_modelMMM[columns_with_missing] = imputer.fit_transform(Bankrupt_modelMMM[columns_with_missing])

# %%
#performing imputation with KNN
imputer=KNNImputer(n_neighbors=5)
Bankrupt_modelKNN[columns_with_missing] = imputer.fit_transform(Bankrupt_modelKNN[columns_with_missing])

# %%
#perfomring imputation with Random Forest
estimator = RandomForestRegressor(n_estimators=3, max_depth= 3)
imputer = IterativeImputer(estimator=estimator, random_state=0)
Bankrupt_modelRF[columns_with_missing] = imputer.fit_transform(Bankrupt_modelRF[columns_with_missing])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_iterative.py:785: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
Bankrupt_modelMMM.isnull().sum()
# Out:
# year                                                   0
# net_profit/total assets                                0
# net_profit/sales                                       0
# Return_On_equity                                       0
# Operating_Income_to_Total_Asset_ratio                  0
# (inventory∗365)/cost_of_products_sold                  0
# working_capital                                        0
# Working_Capital_to_Total_Assets_Ratio                  0
# working_capital_indicator                              0
# Defensive_Interval_Ratio                               0
# Equity_to_Total_Assets_Ratio                           0
# Total_Liabilities/total_assets                         0
# Financial_Leverage                                     0
# Interest_to_Sales                                      0
# Cash_to_assets                                         0
# (receivables∗365)/sales                                0
# total_costs/total_sales                                0
# Cash_conversion_cycle                                  0
# (short-term_liabilities∗365)/cost_of_products_sold)    0
# class                                                  0
# dtype: int64

# %%
Bankrupt_modelMMM.describe()
# Out:
#            year  net_profit/total assets  net_profit/sales  Return_On_equity  \
# count 22828.000                22828.000         22828.000         22828.000
# mean      2.917                    0.072             0.040             0.152
# std       1.302                    0.126             0.079             0.286
# min       1.000                   -0.618            -0.376            -1.338
# 25%       2.000                    0.015             0.010             0.036
# 50%       3.000                    0.059             0.034             0.129
# 75%       4.000                    0.127             0.074             0.268
# max       5.000                    0.755             0.457             1.645
#
#        Operating_Income_to_Total_Asset_ratio  (inventory∗365)/cost_of_products_sold  \
# count                              22828.000                              22828.000
# mean                                   0.087                                 51.211
# std                                    0.140                                 45.923
# min                                   -0.610                                 -0.077
# 25%                                    0.020                                 19.045
# 50%                                    0.071                                 40.153
# 75%                                    0.149                                 69.266
# max                                    0.865                                338.770
#
#        working_capital  Working_Capital_to_Total_Assets_Ratio  working_capital_indicator  \
# count        22828.000                              22828.000                  22828.000
# mean          3458.127                                  0.210                      0.826
# std           6715.651                                  0.265                      0.379
# min         -24790.000                                 -1.865                      0.000
# 25%            133.553                                  0.048                      1.000
# 50%           1397.200                                  0.196                      1.000
# 75%           5254.175                                  0.374                      1.000
# max          29818.000                                  1.000                      1.000
#
#        Defensive_Interval_Ratio  Equity_to_Total_Assets_Ratio  Total_Liabilities/total_assets  \
# count                 22828.000                     22828.000                       22828.000
# mean                     -1.419                         0.501                           0.478
# std                      92.894                         0.265                           0.267
# min                    -541.630                        -1.763                           0.000
# 25%                     -39.878                         0.341                           0.289
# 50%                      -3.176                         0.511                           0.465
# 75%                      34.867                         0.684                           0.640
# max                     547.670                         1.000                           2.743
#
#        Financial_Leverage  Interest_to_Sales  Cash_to_assets  (receivables∗365)/sales  \
# count           22828.000          22828.000       22828.000                22828.000
# mean                2.326              0.004           0.081                   60.890
# std                 1.704              0.008           0.119                   37.943
# min                -6.619             -0.036          -0.441                    0.000
# 25%                 1.427              0.000           0.008                   35.676
# 50%                 1.907              0.000           0.036                   54.112
# 75%                 2.800              0.006           0.110                   76.982
# max                10.813              0.043           0.746                  307.250
#
#        total_costs/total_sales  Cash_conversion_cycle  \
# count                22828.000              22828.000
# mean                     0.936                111.868
# std                      0.102                 60.440
# min                      0.307                 -0.167
# 25%                      0.895                 70.601
# 50%                      0.949                102.051
# 75%                      0.985                140.545
# max                      1.576                537.226
#
#        (short-term_liabilities∗365)/cost_of_products_sold)
# count                                            22828.000
# mean                                                 0.249
# std                                                  0.175
# min                                                 -0.698
# 25%                                                  0.130
# 50%                                                  0.210
# 75%                                                  0.318
# max                                                  1.460

# %%
Bankrupt_modelRF.describe()
# Out:
#            year  net_profit/total assets  net_profit/sales  Return_On_equity  \
# count 22828.000                22828.000         22828.000         22828.000
# mean      2.917                    0.072             0.040             0.152
# std       1.302                    0.126             0.079             0.286
# min       1.000                   -0.618            -0.376            -1.338
# 25%       2.000                    0.015             0.009             0.035
# 50%       3.000                    0.059             0.034             0.129
# 75%       4.000                    0.127             0.074             0.268
# max       5.000                    0.755             0.457             1.645
#
#        Operating_Income_to_Total_Asset_ratio  (inventory∗365)/cost_of_products_sold  \
# count                              22828.000                              22828.000
# mean                                   0.087                                 51.207
# std                                    0.140                                 45.923
# min                                   -0.610                                 -0.077
# 25%                                    0.020                                 19.045
# 50%                                    0.071                                 40.129
# 75%                                    0.149                                 69.266
# max                                    0.865                                338.770
#
#        working_capital  Working_Capital_to_Total_Assets_Ratio  working_capital_indicator  \
# count        22828.000                              22828.000                  22828.000
# mean          3458.124                                  0.210                      0.826
# std           6715.651                                  0.265                      0.379
# min         -24790.000                                 -1.865                      0.000
# 25%            133.553                                  0.048                      1.000
# 50%           1397.200                                  0.196                      1.000
# 75%           5254.175                                  0.374                      1.000
# max          29818.000                                  1.000                      1.000
#
#        Defensive_Interval_Ratio  Equity_to_Total_Assets_Ratio  Total_Liabilities/total_assets  \
# count                 22828.000                     22828.000                       22828.000
# mean                     -1.409                         0.501                           0.478
# std                      92.900                         0.265                           0.267
# min                    -541.630                        -1.763                           0.000
# 25%                     -39.882                         0.341                           0.289
# 50%                      -3.192                         0.511                           0.464
# 75%                      34.916                         0.684                           0.640
# max                     547.670                         1.000                           2.743
#
#        Financial_Leverage  Interest_to_Sales  Cash_to_assets  (receivables∗365)/sales  \
# count           22828.000          22828.000       22828.000                22828.000
# mean                2.327              0.004           0.081                   60.925
# std                 1.704              0.008           0.119                   37.966
# min                -6.619             -0.036          -0.441                    0.000
# 25%                 1.427              0.000           0.008                   35.676
# 50%                 1.907              0.000           0.036                   54.112
# 75%                 2.801              0.006           0.110                   77.040
# max                10.813              0.043           0.746                  307.250
#
#        total_costs/total_sales  Cash_conversion_cycle  \
# count                22828.000              22828.000
# mean                     0.936                111.885
# std                      0.102                 60.447
# min                      0.307                 -0.167
# 25%                      0.895                 70.601
# 50%                      0.949                102.051
# 75%                      0.985                140.562
# max                      1.576                537.226
#
#        (short-term_liabilities∗365)/cost_of_products_sold)
# count                                            22828.000
# mean                                                 0.249
# std                                                  0.175
# min                                                 -0.698
# 25%                                                  0.130
# 50%                                                  0.210
# 75%                                                  0.318
# max                                                  1.460

# %%
Bankrupt_modelRF.isnull().sum()
# Out:
# year                                                   0
# net_profit/total assets                                0
# net_profit/sales                                       0
# Return_On_equity                                       0
# Operating_Income_to_Total_Asset_ratio                  0
# (inventory∗365)/cost_of_products_sold                  0
# working_capital                                        0
# Working_Capital_to_Total_Assets_Ratio                  0
# working_capital_indicator                              0
# Defensive_Interval_Ratio                               0
# Equity_to_Total_Assets_Ratio                           0
# Total_Liabilities/total_assets                         0
# Financial_Leverage                                     0
# Interest_to_Sales                                      0
# Cash_to_assets                                         0
# (receivables∗365)/sales                                0
# total_costs/total_sales                                0
# Cash_conversion_cycle                                  0
# (short-term_liabilities∗365)/cost_of_products_sold)    0
# class                                                  0
# dtype: int64

# %%
Bankrupt_modelRF['class'].value_counts()
# Out:
# class
# 0    21703
# 1     1125
# Name: count, dtype: int64

# %% [markdown]
# #Preparing to model
#
# This research will be looking at the following alograthims:
#
#     1.Logistic Regression
#     2.Decision Tree
#     3.Random Forest
#     4.AdaBoost
#     5.Gradient Boosting

# %%
#performing K-Fold cross-validation to split training sets. Using K= 10 as standard
Bankrupt_model_x =Bankrupt_modelRF.drop(['class'],axis=1)
Bankrupt_model_y =Bankrupt_modelRF['class']

# %%
#defining the number of folds
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle =True, random_state=7)

# %%
for train_index, test_index in kf.split(Bankrupt_model_x):
    # Split data into train and test sets
    X_train, X_test = Bankrupt_model_x.iloc[train_index], Bankrupt_model_x.iloc[test_index]
    y_train, y_test = Bankrupt_model_y.iloc[train_index], Bankrupt_model_y.iloc[test_index]

# %%
y_train.value_counts()
# Out:
# class
# 0    19537
# 1     1009
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'AdaBoost': AdaBoostClassifier(),
    'Gradient Boosting': GradientBoostingClassifier()
}

# %%
#Decision tree :

classifier =  DecisionTreeClassifier(random_state=7)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=7)

# %%
y_pred = pd.Series(classifier.predict(X_test))
y_pred
y_pred.value_counts()
# Out:
# 0    2155
# 1     127
# Name: count, dtype: int64

# %% [markdown]
# #Performance Metrics

# %%
#Confusion matrix for Decision Tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm= confusion_matrix(y_test,y_pred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()

# %%
filename='data.csv'
Bankrupt_model.to_csv(filename,index=False)

# %%
files.download('data.csv')

# %%
print(category_counts)
# Out:
# class
# 0    41314
# 1     2091
# Name: count, dtype: int64

# %%
#files.download(filename)

# %% [markdown]
# #Spliting Datasets into respective Years

# %%
#seperating the year. Year 1
PolishYear1= polish_Dataset.loc[polish_Dataset['year']== 1]
PolishYear1.head()
# Out:
#    year  net profit / total assets  Total Liabilities/total assets  \
# 0     1                   0.200550                         0.37951
# 1     1                   0.209120                         0.49988
# 2     1                   0.248660                         0.69592
# 3     1                   0.081483                         0.30734
# 4     1                   0.187320                         0.61323
#
#    Working Capital to Total Assets Ratio.  Current Ratio.  \
# 0                                 0.39641          2.0472
# 1                                 0.47225          1.9447
# 2                                 0.26713          1.5548
# 3                                 0.45879          2.4928
# 4                                 0.22960          1.4063
#
#    Cash Flow Coverage Ratio  Retained Earnings to Total Assets Ratio  \
# 0                   32.3510                                  0.38825
# 1                   14.7860                                  0.00000
# 2                   -1.1523                                  0.00000
# 3                   51.9520                                  0.14988
# 4                   -7.3128                                  0.18732
#
#    Operating Income to Total Asset ratio  \
# 0                               0.249760
# 1                               0.258340
# 2                               0.309060
# 3                               0.092704
# 4                               0.187320
#
#    book value of equity / total liabilities  Asset Turnover Ratio.  ...  \
# 0                                   1.33050                 1.1389  ...
# 1                                   0.99601                 1.6996  ...
# 2                                   0.43695                 1.3090  ...
# 3                                   1.86610                 1.0571  ...
# 4                                   0.63070                 1.1559  ...
#
#     (sales - cost of products sold) / sales  \
# 0                                  0.121960
# 1                                  0.121300
# 2                                  0.241140
# 3                                  0.054015
# 4                                  0.134850
#
#     (current assets - inventory - short-term liabilities) / (sales – gross profit - depreciation)  \
# 0                                            0.39718
# 1                                            0.42002
# 2                                            0.81774
# 3                                            0.14207
# 4                                            0.48431
#
#    total costs /total sales  long-term liabilities / equity  \
# 0                   0.87804                        0.001924
# 1                   0.85300                        0.000000
# 2                   0.76599                        0.694840
# 3                   0.94598                        0.000000
# 4                   0.86515                        0.124440
#
#     sales / inventory  sales / receivables  \
# 0              8.4160               5.1372
# 1              4.1486               3.2732
# 2              4.9909               3.9510
# 3              4.5746               3.6147
# 4              6.3985               4.3158
#
#    (short-term liabilities ∗365) / sales   sales / short-term liabilities  \
# 0                                 82.658                           4.4158
# 1                                107.350                           3.4000
# 2                                134.270                           2.7185
# 3                                 86.435                           4.2228
# 4                                127.210                           2.8692
#
#     sales / fixed assets  class
# 0                 7.4277      0
# 1                60.9870      0
# 2                 5.2078      0
# 3                 5.5497      0
# 4                 7.8980      0
#
# [5 rows x 66 columns]

# %%
#year 2
PolishYear2 = polish_Dataset.loc[polish_Dataset['year']== 2]
PolishYear2.head()
# Out:
#       year  net profit / total assets  Total Liabilities/total assets  \
# 7027     2                   0.202350                         0.46500
# 7028     2                   0.030073                         0.59563
# 7029     2                   0.257860                         0.29949
# 7030     2                   0.227160                         0.67850
# 7031     2                   0.085443                         0.38039
#
#       Working Capital to Total Assets Ratio.  Current Ratio.  \
# 7027                                0.240380          1.5171
# 7028                                0.186680          1.3382
# 7029                                0.665190          3.2211
# 7030                                0.042784          1.0828
# 7031                                0.359230          1.9444
#
#       Cash Flow Coverage Ratio  Retained Earnings to Total Assets Ratio  \
# 7027                   -14.547                                 0.510690
# 7028                   -37.859                                -0.000319
# 7029                    71.799                                 0.000000
# 7030                   -88.212                                 0.000000
# 7031                    21.731                                 0.187900
#
#       Operating Income to Total Asset ratio  \
# 7027                                0.25366
# 7028                                0.04167
# 7029                                0.31877
# 7030                                0.28505
# 7031                                0.10823
#
#       book value of equity / total liabilities  Asset Turnover Ratio.  ...  \
# 7027                                   0.91816                1.15190  ...
# 7028                                   0.67890                0.32356  ...
# 7029                                   2.33200                1.67620  ...
# 7030                                   0.47384                1.32410  ...
# 7031                                   1.37140                1.11260  ...
#
#        (sales - cost of products sold) / sales  \
# 7027                                   0.13184
# 7028                                   0.12146
# 7029                                   0.16499
# 7030                                   0.29358
# 7031                                   0.10124
#
#        (current assets - inventory - short-term liabilities) / (sales – gross profit - depreciation)  \
# 7027                                           0.473950
# 7028                                           0.074369
# 7029                                           0.369210
# 7030                                           0.706570
# 7031                                           0.163790
#
#       total costs /total sales  long-term liabilities / equity  \
# 7027                   0.86816                         0.00024
# 7028                   0.87235                         0.00000
# 7029                   0.81614                         0.00000
# 7030                   0.78617                         0.48456
# 7031                   0.89876                         0.00000
#
#        sales / inventory  sales / receivables  \
# 7027              8.5487              5.16550
# 7028              1.5264              0.63305
# 7029              4.3325              3.19850
# 7030              5.2309              5.06750
# 7031              5.7035              4.00200
#
#       (short-term liabilities ∗365) / sales   sales / short-term liabilities  \
# 7027                                107.740                          3.38790
# 7028                                622.660                          0.58619
# 7029                                 65.215                          5.59690
# 7030                                142.460                          2.56210
# 7031                                 89.058                          4.09840
#
#        sales / fixed assets  class
# 7027                 5.3440      0
# 7028                 1.2381      0
# 7029                47.4660      0
# 7030                 3.0066      0
# 7031                 5.9874      0
#
# [5 rows x 66 columns]

# %%
#year 3
PolishYear3 = polish_Dataset.loc[polish_Dataset['year']== 3]
PolishYear3.head()
# Out:
#        year  net profit / total assets  Total Liabilities/total assets  \
# 17200     3                   0.174190                         0.41299
# 17201     3                   0.146240                         0.46038
# 17202     3                   0.000595                         0.22612
# 17203     3                   0.024526                         0.43236
# 17204     3                   0.188290                         0.41504
#
#        Working Capital to Total Assets Ratio.  Current Ratio.  \
# 17200                                 0.14371          1.3480
# 17201                                 0.28230          1.6294
# 17202                                 0.48839          3.1599
# 17203                                 0.27546          1.7833
# 17204                                 0.34231          1.9279
#
#        Cash Flow Coverage Ratio  Retained Earnings to Total Assets Ratio  \
# 17200                  -28.9820                                  0.60383
# 17201                    2.5952                                  0.00000
# 17202                   84.8740                                  0.19114
# 17203                  -10.1050                                  0.56944
# 17204                  -58.2740                                  0.00000
#
#        Operating Income to Total Asset ratio  \
# 17200                               0.219460
# 17201                               0.171850
# 17202                               0.004572
# 17203                               0.024526
# 17204                               0.233580
#
#        book value of equity / total liabilities  Asset Turnover Ratio.  ...  \
# 17200                                    1.1225                 1.1961  ...
# 17201                                    1.1721                 1.6018  ...
# 17202                                    2.9881                 1.0077  ...
# 17203                                    1.3057                 1.0509  ...
# 17204                                    1.4094                 1.3393  ...
#
#         (sales - cost of products sold) / sales  \
# 17200                                  0.163960
# 17201                                  0.027516
# 17202                                  0.007639
# 17203                                  0.048398
# 17204                                  0.176480
#
#         (current assets - inventory - short-term liabilities) / (sales – gross profit - depreciation)  \
# 17200                                           0.375740
# 17201                                           0.271000
# 17202                                           0.000881
# 17203                                           0.043445
# 17204                                           0.321880
#
#        total costs /total sales  long-term liabilities / equity  \
# 17200                   0.83604                        0.000007
# 17201                   0.90108                        0.000000
# 17202                   0.99236                        0.000000
# 17203                   0.95160                        0.142980
# 17204                   0.82635                        0.073039
#
#         sales / inventory  sales / receivables  \
# 17200              9.7145               6.2813
# 17201              5.9882               4.1103
# 17202              6.7742               3.7922
# 17203              4.2286               5.0528
# 17204              2.5912               7.0756
#
#        (short-term liabilities ∗365) / sales   sales / short-term liabilities  \
# 17200                                 84.291                           4.3303
# 17201                                102.190                           3.5716
# 17202                                 64.846                           5.6287
# 17203                                 98.783                           3.6950
# 17204                                100.540                           3.6303
#
#         sales / fixed assets  class
# 17200                 4.0341      0
# 17201                 5.9500      0
# 17202                 4.4581      0
# 17203                 3.4844      0
# 17204                 4.6375      0
#
# [5 rows x 66 columns]

# %%
#year 4
PolishYear4 = polish_Dataset.loc[polish_Dataset['year']== 4]
PolishYear4.head()
# Out:
#        year  net profit / total assets  Total Liabilities/total assets  \
# 27703     4                   0.159290                         0.46240
# 27704     4                  -0.127430                         0.46243
# 27705     4                   0.070488                         0.23570
# 27706     4                   0.136760                         0.40538
# 27707     4                  -0.110080                         0.69793
#
#        Working Capital to Total Assets Ratio.  Current Ratio.  \
# 27703                                 0.07773          1.1683
# 27704                                 0.26917          1.7517
# 27705                                 0.52781          3.2393
# 27706                                 0.31543          1.8705
# 27707                                 0.18878          1.2713
#
#        Cash Flow Coverage Ratio  Retained Earnings to Total Assets Ratio  \
# 27703                   -44.853                                 0.467020
# 27704                     7.597                                 0.000925
# 27705                   125.680                                 0.163670
# 27706                    19.115                                 0.504970
# 27707                   -15.344                                 0.000000
#
#        Operating Income to Total Asset ratio  \
# 27703                               0.189480
# 27704                              -0.127430
# 27705                               0.086895
# 27706                               0.136760
# 27707                              -0.110080
#
#        book value of equity / total liabilities  Asset Turnover Ratio.  ...  \
# 27703                                   0.82895                 1.1223  ...
# 27704                                   1.16250                 1.2944  ...
# 27705                                   2.87180                 1.0574  ...
# 27706                                   1.45390                 1.1144  ...
# 27707                                   0.43282                 1.7350  ...
#
#         (sales - cost of products sold) / sales  \
# 27703                                  0.108990
# 27704                                 -0.089372
# 27705                                  0.054286
# 27706                                  0.102630
# 27707                                  0.439880
#
#         (current assets - inventory - short-term liabilities) / (sales – gross profit - depreciation)  \
# 27703                                            0.41557
# 27704                                           -0.23704
# 27705                                            0.10413
# 27706                                            0.23203
# 27707                                           -0.36440
#
#        total costs /total sales  long-term liabilities / equity  \
# 27703                   0.89101                        0.001422
# 27704                   1.06250                        0.150410
# 27705                   0.94571                        0.000000
# 27706                   0.89737                        0.073024
# 27707                   0.57153                        0.000000
#
#         sales / inventory  sales / receivables  \
# 27703              7.7928               4.9914
# 27704              5.4327               3.4629
# 27705              7.1070               3.3808
# 27706              6.1384               4.2241
# 27707             18.8010               2.7925
#
#        (short-term liabilities ∗365) / sales   sales / short-term liabilities  \
# 27703                                119.810                           3.0465
# 27704                                100.970                           3.6150
# 27705                                 76.076                           4.7978
# 27706                                 88.299                           4.1337
# 27707                                146.390                           2.4934
#
#         sales / fixed assets  class
# 27703                 3.0560      0
# 27704                 3.4725      0
# 27705                 4.7818      0
# 27706                 4.6484      0
# 27707                15.0360      0
#
# [5 rows x 66 columns]

# %%
#year 5
PolishYear5 = polish_Dataset.loc[polish_Dataset['year']== 5]
PolishYear5.head()
# Out:
#        year  net profit / total assets  Total Liabilities/total assets  \
# 37495     5                   0.088238                         0.55472
# 37496     5                  -0.006202                         0.48465
# 37497     5                   0.130240                         0.22142
# 37498     5                  -0.089951                         0.88700
# 37499     5                   0.048179                         0.55041
#
#        Working Capital to Total Assets Ratio.  Current Ratio.  \
# 37495                                 0.01134          1.0205
# 37496                                 0.23298          1.5998
# 37497                                 0.57751          3.6082
# 37498                                 0.26927          1.5222
# 37499                                 0.10765          1.2437
#
#        Cash Flow Coverage Ratio  Retained Earnings to Total Assets Ratio  \
# 37495                  -66.5200                                 0.342040
# 37496                    6.1825                                 0.000000
# 37497                  120.0400                                 0.187640
# 37498                  -55.9920                                -0.073957
# 37499                  -22.9590                                 0.000000
#
#        Operating Income to Total Asset ratio  \
# 37495                               0.109490
# 37496                              -0.006202
# 37497                               0.162120
# 37498                              -0.089951
# 37499                               0.059280
#
#        book value of equity / total liabilities  Asset Turnover Ratio.  ...  \
# 37495                                   0.57752                 1.0881  ...
# 37496                                   1.06340                 1.2757  ...
# 37497                                   3.05900                 1.1415  ...
# 37498                                   0.12740                 1.2754  ...
# 37499                                   0.81682                 1.5150  ...
#
#         (sales - cost of products sold) / sales  \
# 37495                                  0.080955
# 37496                                 -0.028591
# 37497                                  0.123960
# 37498                                  0.418840
# 37499                                  0.240400
#
#         (current assets - inventory - short-term liabilities) / (sales – gross profit - depreciation)  \
# 37495                                           0.275430
# 37496                                          -0.012035
# 37497                                           0.192290
# 37498                                          -0.796020
# 37499                                           0.107160
#
#        total costs /total sales  long-term liabilities / equity  \
# 37495                   0.91905                        0.002024
# 37496                   1.00470                        0.152220
# 37497                   0.87604                        0.000000
# 37498                   0.59074                        2.878700
# 37499                   0.77048                        0.139380
#
#         sales / inventory  sales / receivables  \
# 37495              7.2711               4.7343
# 37496              6.0911               3.2749
# 37497              8.7934               2.9870
# 37498              7.6524               3.3302
# 37499             10.1180               4.0950
#
#        (short-term liabilities ∗365) / sales   sales / short-term liabilities  \
# 37495                                142.760                           2.5568
# 37496                                111.140                           3.2841
# 37497                                 71.531                           5.1027
# 37498                                147.560                           2.4735
# 37499                                106.430                           3.4294
#
#         sales / fixed assets  class
# 37495                 3.2597      0
# 37496                 3.3700      0
# 37497                 5.6188      0
# 37498                 5.9299      0
# 37499                 3.3622      0
#
# [5 rows x 66 columns]
